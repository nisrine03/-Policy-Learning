# %% [markdown]
# Importation des Bibliothéques

# %%
import gym
from gym import spaces
import numpy as np
import jax
import jax.numpy as jnp
from flax import linen as nn
import optax
from typing import Dict, Tuple, List, Any
from functools import partial
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
import random
import os
import pickle
from sklearn.model_selection import train_test_split

# %%
class ExperienceBuffer:
    def __init__(self, capacity: int = 10000):
        self.buffer = []
        self.capacity = capacity

    def add(self, state: Dict, action: np.ndarray, reward: float,
            next_state: Dict, done: bool) -> None:
        if len(self.buffer) >= self.capacity:
            self.buffer.pop(0)
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size: int) -> List:
        return random.sample(self.buffer, min(batch_size, len(self.buffer)))

# %% [markdown]
# Implémentation de l'Environement

# %%
class TextFeatureSelectionEnv(gym.Env):
    def __init__(self, embeddings: np.ndarray, labels: np.ndarray,
                 model: Any, batch_size: int = 32):
        super().__init__()

        self._validate_inputs(embeddings, labels)

        self.embeddings = jnp.array(embeddings)
        self.labels = jnp.array(labels)
        self.model = model
        self.batch_size = batch_size

        self.num_samples, self.num_tokens, self.embedding_dim = embeddings.shape

        self.action_space = spaces.Box(
            low=0, high=1,
            shape=(self.num_tokens,),
            dtype=np.float32
        )
        self.observation_space = spaces.Dict({
            'embedding': spaces.Box(
                low=-np.inf, high=np.inf,
                shape=(self.num_tokens, self.embedding_dim),
                dtype=np.float32
            ),
            'mask': spaces.Box(
                low=0, high=1,
                shape=(self.num_tokens,),
                dtype=np.float32
            ),
            'performance': spaces.Box(
                low=0, high=1,
                shape=(1,),
                dtype=np.float32
            )
        })

        self.current_batch_idx = 0
        self.current_episode = 0
        self.performance_history = []
        self.token_usage_stats = jnp.zeros(self.num_tokens)
        self.best_features = {i: [] for i in range(labels.shape[1])}  # Dictionnaire pour les meilleures caractéristiques

    def _validate_inputs(self, embeddings: np.ndarray, labels: np.ndarray) -> None:
        if not isinstance(embeddings, np.ndarray) or not isinstance(labels, np.ndarray):
            raise TypeError("Embeddings and labels must be numpy arrays")
        if len(embeddings.shape) != 3:
            raise ValueError("Embeddings must be 3-dimensional")
        if len(labels.shape) != 2:
            raise ValueError("Labels must be 2-dimensional")
        if embeddings.shape[0] != labels.shape[0]:
            raise ValueError("Number of samples must match between embeddings and labels")

    def _get_batch(self) -> Tuple[jnp.ndarray, jnp.ndarray]:
        start_idx = self.current_batch_idx * self.batch_size
        end_idx = min(start_idx + self.batch_size, self.num_samples)
        return (
            self.embeddings[start_idx:end_idx],
            self.labels[start_idx:end_idx]
        )

    def reset(self) -> Dict[str, jnp.ndarray]:
        key = jax.random.PRNGKey(self.current_episode)
        perm = jax.random.permutation(key, self.num_samples)
        self.embeddings = self.embeddings[perm]
        self.labels = self.labels[perm]

        self.current_batch_idx = 0
        self.current_episode += 1

        batch_embeddings, _ = self._get_batch()

        return {
            'embedding': batch_embeddings[0],
            'mask': jnp.ones(self.num_tokens),
            'performance': jnp.zeros(1)
        }

    @staticmethod
    @jax.jit
    def _compute_metrics(predictions: jnp.ndarray, true_labels: jnp.ndarray) -> Dict[str, jnp.ndarray]:
        pred_labels = jnp.argmax(predictions, axis=1)
        true_labels = jnp.argmax(true_labels, axis=1)
        accuracy = jnp.mean(pred_labels == true_labels)

        return {
            'accuracy': accuracy,
            'pred_labels': pred_labels
        }

    def step(self, action: jnp.ndarray) -> Tuple[Dict[str, jnp.ndarray], float, bool, Dict]:
        batch_embeddings, batch_labels = self._get_batch()

        action = jnp.clip(action, 0, 1)
        masked_embeddings = batch_embeddings * action[:, None]

        predictions = self.model(masked_embeddings)
        predictions = jnp.array(predictions)

        metrics = self._compute_metrics(predictions, batch_labels)

        self.token_usage_stats += action
        self.performance_history.append(metrics['accuracy'].item())

        reward = self._compute_reward(metrics['accuracy'], action)

        self.current_batch_idx += 1
        done = self.current_batch_idx * self.batch_size >= self.num_samples

        current_class_id = int(jnp.argmax(batch_labels[0]))

        selected_features = jnp.where(action > 0.5)[0].tolist()
        feature_names = [f'feature_{i}' for i in selected_features]  # Générer les noms de caractéristiques
        self.best_features[current_class_id].extend(feature_names)

        if not done:
            next_batch_embeddings, _ = self._get_batch()
            next_state = {
                'embedding': next_batch_embeddings[0],
                'mask': action,
                'performance': jnp.array([metrics['accuracy']])
            }
        else:
            next_state = self.reset()

        info = {
            'metrics': metrics,
            'token_usage': self.token_usage_stats / (self.current_batch_idx + 1),
            'class_id': current_class_id,
            'selected_features': selected_features
        }

        return next_state, float(reward), done, info

    def _compute_reward(self, accuracy: float, action: jnp.ndarray) -> float:
        # Contraindre l'action à sélectionner un maximum de 64 caractéristiques
        max_features = 64
        sorted_indices = jnp.argsort(action)[::-1]  # Trier les indices par ordre décroissant de valeur
        top_indices = sorted_indices[:max_features]  # Sélectionner les 64 meilleurs
    
        # Créer une action finale avec uniquement les 64 meilleurs activés
        final_action = jnp.zeros_like(action)
        final_action = final_action.at[top_indices].set(1)  # Activer uniquement les 64 meilleurs
    
        # Calculer la pénalité pour la parcimonie
        sparsity_penalty = 0.1 * jnp.mean(final_action)
    
        # Calculer le nombre de caractéristiques sélectionnées
        num_selected = jnp.sum(final_action)
    
        # Appliquer une pénalité si le nombre de caractéristiques dépasse 64 (ne devrait pas arriver avec la contrainte stricte)
        feature_count_penalty = max(0, (num_selected - max_features) * 0.05)
    
        # Calculer la récompense finale
        return float(accuracy - sparsity_penalty - feature_count_penalty)

# %%
class PolicyNetwork(nn.Module):
    """Attention-based policy network for token selection"""

    @nn.compact
    def __call__(self, state: Dict[str, jnp.ndarray]) -> jnp.ndarray:
        embedding = state['embedding']
        mask = state['mask']
        performance = state['performance']

        if embedding.ndim == 2:
            embedding = jnp.expand_dims(embedding, 0)
            mask = jnp.expand_dims(mask, 0)
            performance = jnp.expand_dims(performance, 0)

        x = nn.Dense(512)(embedding)
        x = nn.LayerNorm()(x)
        x = nn.relu(x)

        q = nn.Dense(512)(x)
        k = nn.Dense(512)(x)
        v = nn.Dense(512)(x)

        scale = jnp.sqrt(512)
        scores = jnp.einsum('bik,bjk->bij', q, k) / scale
        attention_weights = nn.softmax(scores, axis=-1)
        attended = jnp.einsum('bij,bjk->bik', attention_weights, v)

        mask_info = jnp.expand_dims(mask, -1)
        perf_info = jnp.broadcast_to(
            jnp.expand_dims(performance, 1),
            (attended.shape[0], attended.shape[1], 1)
        )

        x = jnp.concatenate([attended, mask_info, perf_info], axis=-1)

        x = nn.Dense(256)(x)
        x = nn.relu(x)
        x = nn.Dense(1)(x)
        x = nn.sigmoid(x)

        return x.squeeze((-1, 0))

# %%
class RLAgent:
    def __init__(
        self,
        env: gym.Env,
        model: Any,  # Ajoutez le modèle ici
        learning_rate: float = 1e-4,
        gamma: float = 0.99,
        buffer_capacity: int = 10000
    ):
        self.env = env
        self.model = model  # Stockez le modèle dans l'agent
        self.gamma = gamma
        self.experience_buffer = ExperienceBuffer(buffer_capacity)

        # Initialize policy
        self.policy = PolicyNetwork()
        self.optimizer = optax.adam(learning_rate)

        # Initialize parameters
        dummy_state = env.reset()
        self.params = self.policy.init(
            jax.random.PRNGKey(0),
            {k: jnp.expand_dims(v, 0) for k, v in dummy_state.items()}
        )
        self.opt_state = self.optimizer.init(self.params)
        # Initialiser best_features pour chaque classe
        self.best_features = {i: [] for i in range(env.labels.shape[1])}  # Dictionnaire pour les meilleures caractéristiques

    @partial(jax.jit, static_argnums=(0,))
    def _policy_step(
        self,
        params: Dict,
        state: Dict[str, jnp.ndarray],
        key: jnp.ndarray,
        k: int = 10
    ) -> Tuple[jnp.ndarray, jnp.ndarray]:
        logits = self.policy.apply(params, state)

        # Ajouter du bruit pour l'exploration
        noise = jax.random.normal(key, logits.shape) * 0.1
        logits = logits + noise

        action = self._select_top_k_features(logits, k)

        log_prob = jnp.sum(
            action * jnp.log(logits + 1e-8) +
            (1 - action) * jnp.log(1 - logits + 1e-8)
        )
        return action, log_prob

    @partial(jax.jit, static_argnums=(0,))
    def _compute_loss(self, params: Dict, batch: List) -> jnp.ndarray:
        total_loss = 0.0
        for state, action, reward, _, _ in batch:
            logits = self.policy.apply(params, state)
            log_prob = jnp.sum(
                action * jnp.log(logits + 1e-8) +
                (1 - action) * jnp.log(1 - logits + 1e-8)
            )
            total_loss -= log_prob * reward
        return total_loss / len(batch)

    def _select_top_k_features(self, logits: jnp.ndarray, k: int) -> jnp.ndarray:
        k = jnp.clip(k, 0, logits.shape[0])  # Assurer que k ne dépasse pas le nombre de logits
        threshold = jnp.sort(logits)[-k]
        return jnp.where(logits >= threshold, 1.0, 0.0)

    def train(
        self,
        num_episodes: int,
        max_steps_per_episode: int = 100,
        batch_size: int = 32,
        max_features: int = 64,
        save_dir: str = "models"
    ) -> Tuple[List[float], Dict[int, np.ndarray]]:
        self.training = True
        returns = []
        best_return = float('-inf')

        os.makedirs(save_dir, exist_ok=True)

        try:
            for episode in range(num_episodes):
                print(f"\n{'='*20} Épisode {episode + 1}/{num_episodes} {'='*20}")

                state = self.env.reset()
                episode_return = 0
                episode_steps = 0

                while episode_steps < max_steps_per_episode:
                    print(f"\nÉtape {episode_steps + 1}/{max_steps_per_episode}")

                    key = jax.random.PRNGKey(episode * max_steps_per_episode + episode_steps)

                    action, log_prob = self._policy_step(
                        self.params,
                        state,
                        key,
                        k=random.randint(1, max_features)
                    )

                    next_state, reward, done, info = self.env.step(action)
                    episode_return += reward

                    self.experience_buffer.add(state, action, reward, next_state, done)

                    if len(self.experience_buffer.buffer) >= batch_size:
                        batch = self.experience_buffer.sample(batch_size)
                        loss = self._compute_loss(self.params, batch)
                        grads = jax.grad(lambda p: self._compute_loss(p, batch))(self.params)
                        updates, self.opt_state = self.optimizer.update(grads, self.opt_state)
                        self.params = optax.apply_updates(self.params, updates)

                    print(f"Récompense: {reward:.4f}, Retour cumulé: {episode_return:.4f}, Caractéristiques sélectionnées: {info['selected_features']}")

                    if done:
                        print("Épisode terminé")
                        break

                    state = next_state
                    episode_steps += 1

                returns.append(episode_return)

                print(f"\nStatistiques de l'épisode {episode + 1}:")
                print(f"Retour total: {episode_return:.4f}")

        except KeyboardInterrupt:
            print("\nEntraînement interrompu par l'utilisateur")

        finally:
            self.training = False

            if returns:
                print("\nStatistiques finales d'entraînement:")
                print(f"Nombre total d'épisodes complétés: {len(returns)}")
                print(f"Meilleur retour: {max(returns):.4f}")
                print(f"Retour moyen: {np.mean(returns):.4f}")
            else:
                print("Aucun épisode n'a été complété.")

        self.display_best_features()  # Afficher les meilleures caractéristiques à la fin
        return returns, {}

    def display_best_features(self):
        print("\nMeilleures caractéristiques par classe :")
        for class_id, features in self.best_features.items():
            print(f"Meilleures caractéristiques pour la classe {class_id}: {set(features)}")

    def save_model(self, path: str):
        """Sauvegarde les paramètres du modèle dans un fichier."""
        with open(path, 'wb') as f:
            pickle.dump(self.params, f)
        print(f"Modèle sauvegardé à : {path}")

    def evaluate(self, test_embeddings: np.ndarray, test_labels: np.ndarray) -> float:
        """Évalue le modèle sur l'ensemble de test."""
        self.training = False  # Assurez-vous que nous ne sommes pas en mode entraînement
        test_env = TextFeatureSelectionEnv(test_embeddings, test_labels, self.model)
        state = test_env.reset()
        total_accuracy = 0.0
        num_batches = 0

        while True:
            action = self._select_top_k_features(self.policy.apply(self.params, state), k=test_env.num_tokens)
            next_state, reward, done, info = test_env.step(action)
            metrics = info['metrics']
            total_accuracy += metrics['accuracy']
            num_batches += 1

            if done:
                break
            state = next_state
        print(f"Total Accuracy: {total_accuracy}, Number of Batches: {num_batches}")  # Debugging line
        return total_accuracy / num_batches if num_batches > 0 else 0.0

# %%
# Chargement des données
embeddings = np.load("embeddings.npy")  # de taille (5000,128,768)
labels = np.load("labels_one_hot.npy")  # de taille (5000,)
model = load_model('modele.keras')

# %%
# Préparer les indices pour chaque classe
num_classes = labels.shape[1]
train_embeddings = []
test_embeddings = []
train_labels = []
test_labels = []

for class_id in range(num_classes):
    class_indices = np.where(labels[:, class_id] == 1)[0]
    train_idx, test_idx = train_test_split(class_indices, test_size=0.2, random_state=42)
    train_embeddings.append(embeddings[train_idx])
    test_embeddings.append(embeddings[test_idx])
    train_labels.append(labels[train_idx])
    test_labels.append(labels[test_idx])

train_embeddings = np.vstack(train_embeddings)
test_embeddings = np.vstack(test_embeddings)
train_labels = np.vstack(train_labels)
test_labels = np.vstack(test_labels)

# %%
print(f"Taille des données d'entraînement : {train_embeddings.shape}, {train_labels.shape}")
print(f"Taille des données de test : {test_embeddings.shape}, {test_labels.shape}")
# Out:
# Taille des données d'entraînement : (4000, 128, 768), (4000, 10)
# Taille des données de test : (1000, 128, 768), (1000, 10)

# %%
env = TextFeatureSelectionEnv(train_embeddings, train_labels, model)
agent = RLAgent(env, model)

# %%
# Lancer l'entraînement
returns, feature_counts = agent.train(
    num_episodes=100,
    max_steps_per_episode=100,
    batch_size=32,
    max_features=64
)
# Out:
# ==================== Épisode 1/100 ====================
#
# Étape 1/100
# Récompense: 0.2201, Retour cumulé: 0.2201
# Caractéristiques sélectionnées : [6, 7, 15, 16, 20, 25, 33, 42, 44, 52, 54, 67, 77, 78, 85, 92, 95, 102, 107, 111, 115, 116, 120, 124]
#
# Étape 21/100
# Récompense: 0.1914, Retour cumulé: 4.2331
# Caractéristiques sélectionnées : [0, 4, 5, 7, 11, 12, 17, 37, 52, 58, 60, 63, 68, 78, 81, 89, 92, 94, 95, 102, 109, 112, 113, 119, 123]
#
# Étape 41/100
# Récompense: 0.1588, Retour cumulé: 8.0265
# Caractéristiques sélectionnées : [10, 14, 21, 24, 25, 27, 38, 55, 56, 59, 70, 76, 77, 79, 81, 93, 99, 104, 107, 112, 122, 124]
#
# Étape 61/100
# Récompense: 0.2135, Retour cumulé: 12.2148
# Caractéristiques sélectionnées : [5, 7, 8, 9, 30, 32, 33, 34, 37, 42, 48, 52, 61, 71, 76, 85, 90, 92, 93, 98, 107, 109, 125]
#
# Étape 81/100
# Récompense: 0.2598, Retour cumulé: 16.2088
# Caractéristiques sélectionnées : [0, 4, 5, 7, 9, 12, 17, 20, 26, 27, 29, 43, 52, 58, 59, 60, 63, 78, 81, 96, 102, 109, 112, 123, 126]
#
# Étape 100/100
# Récompense: 0.2120, Retour cumulé: 20.0230
# Caractéristiques sélectionnées : [6, 7, 16, 20, 22, 25, 42, 50, 52, 53, 67, 70, 78, 85, 88, 95, 102, 104, 105, 111, 120, 124]
#
#
# Statistiques de l'épisode 1:
# Retour total: 20.0230
#
# ==================== Épisode 2/100 ====================
#
# Étape 1/100
# Récompense: 0.1674, Retour cumulé: 0.1674
# Caractéristiques sélectionnées : [0, 6, 7, 16, 20, 25, 27, 29, 42, 52, 64, 67, 73, 78, 85, 87, 95, 100, 102, 103, 107, 111, 120, 124]
#
# Étape 21/100
# Récompense: 0.1133, Retour cumulé: 4.4737
# Caractéristiques sélectionnées : [10, 14, 24, 25, 29, 38, 45, 55, 56, 59, 67, 70, 76, 79, 81, 86, 91, 93, 99, 104, 109, 112, 122, 124]
#
# Étape 41/100
# Récompense: 0.1279, Retour cumulé: 8.6440
# Caractéristiques sélectionnées : [4, 12, 13, 14, 18, 33, 34, 42, 47, 57, 58, 59, 62, 69, 77, 80, 82, 83, 87, 99, 114, 119, 123]
#
# Étape 61/100
# Récompense: 0.1074, Retour cumulé: 12.6305
# Caractéristiques sélectionnées : [0, 6, 7, 16, 20, 21, 25, 31, 39, 42, 52, 55, 65, 67, 71, 78, 85, 95, 102, 108, 111, 112, 120, 124, 126]
#
# Étape 81/100
# Récompense: 0.2191, Retour cumulé: 16.6867
# Caractéristiques sélectionnées : [1, 2, 6, 7, 11, 16, 20, 25, 32, 42, 51, 52, 53, 64, 67, 78, 79, 82, 85, 95, 102, 111, 120, 124]
#
# Étape 100/100
# Récompense: 0.2016, Retour cumulé: 20.4819
# Caractéristiques sélectionnées : [4, 12, 18, 21, 27, 33, 34, 42, 47, 48, 50, 57, 58, 59, 62, 71, 77, 78, 80, 83, 87, 99, 114, 126]
#
#
# Statistiques de l'épisode 2:
# Retour total: 20.4819
#
# ==================== Épisode 3/100 ====================
#
# Étape 1/100
# Récompense: 0.1000, Retour cumulé: 0.1000
# Caractéristiques sélectionnées : [10, 14, 17, 24, 25, 38, 48, 54, 55, 56, 59, 70, 79, 81, 82, 93, 99, 110, 112, 113, 122]
#
# Étape 21/100
# Récompense: 0.3036, Retour cumulé: 4.2057
# Caractéristiques sélectionnées : [0, 6, 7, 12, 14, 20, 23, 34, 36, 40, 44, 79, 91, 100, 102, 107, 109, 111, 113, 114, 125, 126, 127]
#
# Étape 41/100
# Récompense: 0.1888, Retour cumulé: 8.1904
# Caractéristiques sélectionnées : [0, 4, 12, 17, 32, 33, 34, 41, 42, 47, 57, 58, 59, 60, 62, 67, 75, 77, 80, 83, 87, 99, 102, 114, 127]
#
# Étape 61/100
# Récompense: 0.1885, Retour cumulé: 12.6534
# Caractéristiques sélectionnées : [0, 6, 7, 14, 19, 20, 27, 34, 40, 42, 49, 79, 89, 92, 100, 102, 106, 109, 111, 114, 121, 125, 126, 127]
#
# Étape 81/100
# Récompense: 0.1912, Retour cumulé: 16.7402
# Caractéristiques sélectionnées : [1, 7, 15, 21, 22, 23, 28, 31, 42, 51, 60, 68, 69, 93, 101, 110, 115, 117, 119, 125, 127]
#
# Étape 100/100
# Récompense: 0.2366, Retour cumulé: 20.7762
# Caractéristiques sélectionnées : [0, 10, 23, 26, 27, 34, 47, 48, 52, 53, 58, 62, 64, 73, 75, 78, 79, 83, 84, 90, 93, 94, 99, 104, 106, 112]
#
#
# Statistiques de l'épisode 3:
# Retour total: 20.7762
#
# ==================== Épisode 4/100 ====================
#
# Étape 1/100
# Récompense: 0.1414, Retour cumulé: 0.1414
# Caractéristiques sélectionnées : [0, 8, 10, 19, 47, 49, 53, 57, 62, 72, 73, 78, 79, 83, 84, 90, 94, 99, 105, 106, 112, 117]
#
# Étape 21/100
# Récompense: 0.1805, Retour cumulé: 4.1501
# Caractéristiques sélectionnées : [8, 9, 20, 21, 32, 34, 37, 38, 47, 48, 52, 61, 67, 69, 71, 76, 90, 93, 98, 108, 109, 125]
#
# Étape 41/100
# Récompense: 0.1940, Retour cumulé: 8.5788
# Caractéristiques sélectionnées : [8, 9, 11, 15, 32, 34, 37, 48, 52, 61, 71, 76, 84, 90, 92, 93, 97, 98, 102, 108, 109, 125]
#
# Étape 61/100
# Récompense: 0.2317, Retour cumulé: 12.6980
# Caractéristiques sélectionnées : [2, 13, 14, 16, 19, 23, 27, 29, 35, 37, 42, 60, 69, 71, 93, 96, 98, 107, 125, 126]
#
# Étape 81/100
# Récompense: 0.1869, Retour cumulé: 16.8530
# Caractéristiques sélectionnées : [0, 6, 7, 8, 17, 20, 26, 34, 35, 40, 54, 60, 71, 74, 79, 82, 100, 102, 109, 111, 114, 124, 125, 126, 127]
#
# Étape 100/100
# Récompense: 0.1282, Retour cumulé: 20.8252
# Caractéristiques sélectionnées : [0, 4, 6, 7, 20, 34, 36, 40, 57, 64, 66, 78, 79, 100, 102, 104, 109, 111, 114, 125, 126, 127]
#
#
# Statistiques de l'épisode 4:
# Retour total: 20.8252
#
# ==================== Épisode 5/100 ====================
#
# Étape 1/100
# Récompense: 0.1872, Retour cumulé: 0.1872
# Caractéristiques sélectionnées : [7, 10, 14, 15, 24, 25, 37, 38, 50, 55, 56, 59, 70, 76, 79, 81, 87, 93, 99, 104, 112, 116, 122]
#
# Étape 21/100
# Récompense: 0.2096, Retour cumulé: 4.3417
# Caractéristiques sélectionnées : [4, 5, 8, 9, 21, 29, 30, 32, 34, 37, 48, 52, 57, 61, 71, 76, 90, 93, 94, 98, 109, 125]
#
# Étape 41/100
# Récompense: 0.2183, Retour cumulé: 8.8042
# Caractéristiques sélectionnées : [10, 14, 24, 25, 33, 38, 55, 56, 59, 70, 77, 79, 80, 81, 88, 92, 93, 99, 100, 102, 112, 114, 122, 124]
#
# Étape 61/100
# Récompense: 0.2521, Retour cumulé: 13.2083
# Caractéristiques sélectionnées : [7, 15, 23, 28, 31, 36, 42, 47, 50, 51, 60, 64, 68, 69, 84, 91, 92, 93, 110, 115, 117, 119, 124, 125, 126, 127]
#
# Étape 81/100
# Récompense: 0.1901, Retour cumulé: 17.6038
# Caractéristiques sélectionnées : [0, 3, 6, 7, 8, 14, 20, 34, 40, 42, 69, 79, 93, 94, 96, 100, 102, 109, 111, 114, 125, 126, 127]
#
# Étape 100/100
# Récompense: 0.2079, Retour cumulé: 21.7329
# Caractéristiques sélectionnées : [8, 10, 14, 24, 25, 26, 38, 42, 52, 55, 56, 59, 70, 79, 81, 82, 88, 93, 99, 105, 109, 112, 122, 124]
#
#
# Statistiques de l'épisode 5:
# Retour total: 21.7329
#
# ==================== Épisode 6/100 ====================
#
# Étape 1/100
# Récompense: 0.2206, Retour cumulé: 0.2206
# Caractéristiques sélectionnées : [19, 23, 26, 37, 39, 42, 45, 53, 54, 55, 56, 61, 66, 67, 70, 80, 87, 95, 96, 101, 106, 107, 108, 111, 118, 126]
#
# Étape 21/100
# Récompense: 0.1786, Retour cumulé: 4.6662
# Caractéristiques sélectionnées : [8, 9, 14, 20, 32, 34, 37, 39, 45, 48, 52, 53, 61, 71, 76, 81, 90, 93, 94, 98, 106, 109, 125]
#
# Étape 41/100
# Récompense: 0.2176, Retour cumulé: 9.0765
# Caractéristiques sélectionnées : [2, 6, 7, 15, 16, 20, 25, 35, 42, 52, 60, 65, 67, 71, 72, 78, 85, 91, 95, 102, 103, 105, 111, 120, 124]
#
# Étape 61/100
# Récompense: 0.1846, Retour cumulé: 13.4802
# Caractéristiques sélectionnées : [0, 10, 37, 39, 45, 47, 50, 53, 62, 71, 73, 78, 79, 83, 84, 90, 94, 99, 101, 106, 112, 118, 120, 122]
#
# Étape 81/100
# Récompense: 0.2896, Retour cumulé: 17.8378
# Caractéristiques sélectionnées : [4, 14, 16, 19, 23, 26, 27, 29, 32, 35, 36, 37, 41, 42, 45, 60, 69, 74, 82, 88, 93, 98, 103, 107, 124, 125]
#
# Étape 100/100
# Récompense: 0.2133, Retour cumulé: 21.9136
# Caractéristiques sélectionnées : [0, 2, 6, 7, 20, 28, 29, 34, 38, 40, 56, 63, 73, 76, 79, 100, 102, 109, 111, 114, 119, 125, 126, 127]
#
#
# Statistiques de l'épisode 6:
# Retour total: 21.9136
#
# ==================== Épisode 7/100 ====================
#
# Étape 1/100
# Récompense: 0.2460, Retour cumulé: 0.2460
# Caractéristiques sélectionnées : [0, 6, 7, 16, 20, 34, 38, 40, 43, 46, 64, 65, 79, 100, 102, 109, 111, 114, 125, 126, 127]
#
# Étape 21/100
# Récompense: 0.2834, Retour cumulé: 5.0359
# Caractéristiques sélectionnées : [1, 2, 14, 16, 19, 23, 24, 27, 29, 35, 37, 40, 42, 43, 49, 57, 60, 68, 69, 80, 93, 98, 107, 125]
#
# Étape 41/100
# Récompense: 0.2443, Retour cumulé: 9.7253
# Caractéristiques sélectionnées : [4, 12, 20, 23, 26, 28, 33, 34, 42, 47, 55, 57, 58, 59, 62, 65, 77, 80, 83, 87, 108, 114, 119, 125]
#
# Étape 61/100
# Récompense: 0.2404, Retour cumulé: 14.1924
# Caractéristiques sélectionnées : [8, 10, 14, 24, 25, 38, 55, 56, 59, 65, 67, 70, 77, 79, 81, 82, 93, 97, 99, 101, 102, 110, 112, 114, 122, 125]
#
# Étape 81/100
# Récompense: 0.2412, Retour cumulé: 18.7964
# Caractéristiques sélectionnées : [8, 9, 24, 32, 34, 37, 43, 44, 47, 48, 52, 61, 71, 75, 76, 78, 86, 90, 93, 98, 100, 104, 109, 111, 123, 125]
#
# Étape 100/100
# Récompense: 0.2695, Retour cumulé: 22.9014
# Caractéristiques sélectionnées : [0, 6, 7, 18, 20, 22, 34, 40, 48, 57, 72, 79, 100, 102, 105, 109, 111, 114, 125, 126, 127]
#
#
# Statistiques de l'épisode 7:
# Retour total: 22.9014
#
# ==================== Épisode 8/100 ====================
#
# Étape 1/100
# Récompense: 0.2171, Retour cumulé: 0.2171
# Caractéristiques sélectionnées : [4, 15, 23, 28, 31, 41, 42, 50, 53, 56, 60, 68, 69, 82, 88, 93, 106, 110, 115, 117, 119, 125, 127]
#
# Étape 21/100
# Récompense: 0.2889, Retour cumulé: 4.8270
# Caractéristiques sélectionnées : [1, 9, 19, 21, 23, 37, 39, 42, 45, 53, 54, 55, 56, 61, 63, 77, 87, 95, 106, 107, 108, 121]
#
# Étape 41/100
# Récompense: 0.2966, Retour cumulé: 9.5811
# Caractéristiques sélectionnées : [2, 4, 8, 12, 14, 15, 29, 32, 33, 34, 40, 42, 47, 57, 58, 59, 62, 77, 80, 83, 86, 87, 95, 110, 113, 114]
#
# Étape 61/100
# Récompense: 0.1894, Retour cumulé: 14.2148
# Caractéristiques sélectionnées : [2, 14, 16, 19, 22, 23, 27, 29, 35, 37, 38, 42, 59, 60, 65, 69, 80, 93, 98, 107, 114, 122, 125]
#
# Étape 81/100
# Récompense: 0.3037, Retour cumulé: 18.7330
# Caractéristiques sélectionnées : [0, 6, 7, 20, 34, 40, 57, 58, 59, 61, 66, 69, 72, 78, 79, 100, 102, 109, 111, 114, 125, 126, 127]
#
# Étape 100/100
# Récompense: 0.2412, Retour cumulé: 23.5890
# Caractéristiques sélectionnées : [12, 14, 16, 19, 20, 23, 26, 27, 29, 35, 37, 40, 42, 60, 69, 76, 79, 87, 93, 95, 98, 106, 107, 121, 125]
#
#
# Statistiques de l'épisode 8:
# Retour total: 23.5890
#
# ==================== Épisode 9/100 ====================
#
# Étape 1/100
# Récompense: 0.3274, Retour cumulé: 0.3274
# Caractéristiques sélectionnées : [5, 6, 7, 16, 19, 20, 25, 42, 52, 67, 71, 78, 85, 92, 95, 101, 102, 109, 111, 113, 120, 124]
#
# Étape 21/100
# Récompense: 0.2926, Retour cumulé: 5.0193
# Caractéristiques sélectionnées : [2, 10, 14, 18, 24, 25, 30, 38, 43, 55, 56, 59, 62, 63, 67, 70, 79, 81, 93, 99, 112, 122]
#
# Étape 41/100
# Récompense: 0.1589, Retour cumulé: 9.4751
# Caractéristiques sélectionnées : [5, 6, 7, 16, 20, 25, 42, 52, 56, 66, 67, 76, 78, 85, 94, 95, 102, 111, 114, 120, 123, 124]
#
# Étape 61/100
# Récompense: 0.2042, Retour cumulé: 14.2510
# Caractéristiques sélectionnées : [2, 10, 14, 20, 24, 25, 31, 38, 46, 52, 55, 56, 58, 59, 62, 66, 70, 79, 81, 86, 93, 99, 112, 122]
#
# Étape 81/100
# Récompense: 0.2807, Retour cumulé: 18.3575
# Caractéristiques sélectionnées : [4, 12, 33, 34, 35, 42, 47, 57, 58, 59, 62, 73, 74, 77, 80, 83, 87, 96, 98, 108, 112, 113, 114, 115, 126]
#
# Étape 100/100
# Récompense: 0.2517, Retour cumulé: 22.5195
# Caractéristiques sélectionnées : [3, 8, 9, 32, 34, 37, 42, 48, 52, 61, 70, 71, 76, 82, 90, 93, 98, 102, 109, 114, 117, 125]
#
#
# Statistiques de l'épisode 9:
# Retour total: 22.5195
#
# ==================== Épisode 10/100 ====================
#
# Étape 1/100
# Récompense: 0.2083, Retour cumulé: 0.2083
# Caractéristiques sélectionnées : [0, 3, 4, 6, 7, 20, 34, 40, 41, 57, 65, 79, 82, 85, 88, 89, 92, 100, 102, 109, 111, 114, 125, 126, 127]
#
# Étape 21/100
# Récompense: 0.1786, Retour cumulé: 5.1954
# Caractéristiques sélectionnées : [6, 7, 16, 20, 21, 25, 42, 52, 61, 67, 70, 75, 78, 85, 93, 95, 96, 98, 99, 102, 107, 111, 120, 123, 124]
#
# Étape 41/100
# Récompense: 0.1509, Retour cumulé: 9.6894
# Caractéristiques sélectionnées : [0, 4, 5, 7, 12, 13, 15, 28, 52, 58, 59, 60, 63, 78, 81, 83, 90, 100, 102, 109, 110, 112, 123]
#
# Étape 61/100
# Récompense: 0.2351, Retour cumulé: 14.2357
# Caractéristiques sélectionnées : [0, 4, 5, 7, 12, 18, 26, 28, 37, 40, 45, 52, 58, 60, 63, 78, 81, 84, 102, 109, 112, 116, 122, 123]
#
# Étape 81/100
# Récompense: 0.2953, Retour cumulé: 19.1806
# Caractéristiques sélectionnées : [4, 7, 10, 14, 24, 25, 35, 38, 48, 55, 56, 59, 70, 79, 81, 85, 93, 99, 112, 113, 115, 116, 122]
#
# Étape 100/100
# Récompense: 0.1952, Retour cumulé: 23.6753
# Caractéristiques sélectionnées : [0, 4, 5, 6, 7, 12, 17, 22, 41, 52, 55, 58, 60, 63, 78, 81, 91, 102, 108, 109, 110, 112, 123]
#
#
# Statistiques de l'épisode 10:
# Retour total: 23.6753
#
# ==================== Épisode 11/100 ====================
#
# Étape 1/100
# Récompense: 0.2210, Retour cumulé: 0.2210
# Caractéristiques sélectionnées : [4, 6, 12, 22, 23, 33, 34, 36, 37, 38, 40, 42, 46, 47, 57, 58, 59, 62, 77, 80, 83, 87, 114, 119]
#
# Étape 21/100
# Récompense: 0.1702, Retour cumulé: 4.9450
# Caractéristiques sélectionnées : [5, 6, 7, 8, 16, 20, 25, 40, 42, 44, 52, 67, 73, 78, 85, 95, 97, 102, 104, 111, 120, 121, 124]
#
# Étape 41/100
# Récompense: 0.2156, Retour cumulé: 9.9063
# Caractéristiques sélectionnées : [12, 15, 22, 23, 28, 31, 32, 42, 59, 60, 64, 68, 69, 87, 89, 93, 96, 108, 110, 114, 115, 117, 119, 123, 125, 127]
#
# Étape 61/100
# Récompense: 0.2646, Retour cumulé: 14.6547
# Caractéristiques sélectionnées : [0, 4, 5, 7, 12, 22, 41, 46, 52, 55, 58, 60, 63, 77, 78, 81, 99, 101, 102, 109, 111, 112, 118, 120, 123]
#
# Étape 81/100
# Récompense: 0.2120, Retour cumulé: 19.5602
# Caractéristiques sélectionnées : [3, 4, 12, 24, 33, 34, 40, 42, 47, 57, 58, 59, 61, 62, 71, 77, 80, 83, 87, 110, 114, 117, 123]
#
# Étape 100/100
# Récompense: 0.2979, Retour cumulé: 24.2351
# Caractéristiques sélectionnées : [10, 14, 16, 19, 23, 27, 29, 35, 37, 42, 60, 69, 70, 72, 77, 90, 91, 93, 98, 104, 107, 111, 116, 125]
#
#
# Statistiques de l'épisode 11:
# Retour total: 24.2351
#
# ==================== Épisode 12/100 ====================
#
# Étape 1/100
# Récompense: 0.2793, Retour cumulé: 0.2793
# Caractéristiques sélectionnées : [4, 12, 19, 25, 37, 39, 42, 43, 45, 53, 54, 55, 56, 61, 72, 83, 86, 87, 95, 103, 106, 107, 108, 116]
#
# Étape 21/100
# Récompense: 0.1990, Retour cumulé: 4.9770
# Caractéristiques sélectionnées : [0, 4, 6, 7, 10, 12, 19, 20, 21, 25, 30, 33, 34, 40, 79, 100, 102, 109, 111, 114, 125, 126, 127]
#
# Étape 41/100
# Récompense: 0.1839, Retour cumulé: 9.8056
# Caractéristiques sélectionnées : [0, 6, 7, 11, 12, 14, 20, 34, 40, 43, 44, 58, 59, 78, 79, 100, 102, 103, 104, 109, 111, 112, 114, 118, 125, 126, 127]
#
# Étape 61/100
# Récompense: 0.3110, Retour cumulé: 14.8751
# Caractéristiques sélectionnées : [4, 9, 12, 29, 31, 33, 34, 39, 42, 47, 57, 58, 59, 62, 67, 77, 80, 81, 83, 87, 96, 109, 114, 126]
#
# Étape 81/100
# Récompense: 0.2458, Retour cumulé: 19.5546
# Caractéristiques sélectionnées : [0, 9, 10, 32, 35, 46, 47, 53, 58, 60, 62, 73, 75, 78, 79, 83, 84, 90, 94, 96, 97, 99, 106, 112]
#
# Étape 100/100
# Récompense: 0.2543, Retour cumulé: 24.4103
# Caractéristiques sélectionnées : [0, 8, 9, 32, 34, 37, 48, 52, 56, 59, 61, 62, 63, 71, 76, 90, 93, 98, 109, 113, 115, 123, 125]
#
#
# Statistiques de l'épisode 12:
# Retour total: 24.4103
#
# ==================== Épisode 13/100 ====================
#
# Étape 1/100
# Récompense: 0.2561, Retour cumulé: 0.2561
# Caractéristiques sélectionnées : [8, 9, 30, 32, 34, 37, 44, 45, 48, 52, 61, 62, 71, 72, 76, 83, 90, 93, 97, 98, 99, 104, 109, 125]
#
# Étape 21/100
# Récompense: 0.2466, Retour cumulé: 5.3197
# Caractéristiques sélectionnées : [8, 18, 19, 21, 29, 35, 37, 39, 42, 45, 53, 54, 55, 56, 61, 64, 87, 95, 101, 106, 107, 108, 114]
#
# Étape 41/100
# Récompense: 0.2692, Retour cumulé: 9.7525
# Caractéristiques sélectionnées : [6, 9, 15, 23, 28, 31, 42, 49, 56, 60, 68, 69, 90, 93, 108, 110, 115, 117, 118, 119, 125, 127]
#
# Étape 61/100
# Récompense: 0.2320, Retour cumulé: 14.6964
# Caractéristiques sélectionnées : [10, 14, 22, 24, 25, 29, 38, 53, 55, 56, 59, 70, 74, 79, 81, 92, 93, 97, 99, 109, 112, 113, 122]
#
# Étape 81/100
# Récompense: 0.2286, Retour cumulé: 19.5080
# Caractéristiques sélectionnées : [2, 4, 12, 20, 24, 31, 33, 34, 37, 42, 47, 57, 58, 59, 62, 77, 79, 80, 83, 85, 87, 88, 111, 114, 118, 120, 124]
#
# Étape 100/100
# Récompense: 0.2570, Retour cumulé: 24.1453
# Caractéristiques sélectionnées : [0, 10, 14, 21, 24, 25, 26, 28, 30, 38, 44, 48, 55, 56, 59, 70, 71, 79, 81, 93, 99, 102, 107, 112, 122]
#
#
# Statistiques de l'épisode 13:
# Retour total: 24.1453
#
# ==================== Épisode 14/100 ====================
#
# Étape 1/100
# Récompense: 0.2125, Retour cumulé: 0.2125
# Caractéristiques sélectionnées : [10, 14, 22, 24, 25, 38, 43, 46, 47, 55, 56, 59, 66, 70, 73, 76, 79, 81, 90, 93, 97, 99, 102, 110, 112, 122]
#
# Étape 21/100
# Récompense: 0.2970, Retour cumulé: 5.0861
# Caractéristiques sélectionnées : [0, 2, 4, 5, 7, 12, 14, 21, 29, 33, 52, 58, 60, 63, 78, 81, 87, 89, 91, 97, 100, 102, 109, 112, 123]
#
# Étape 41/100
# Récompense: 0.1823, Retour cumulé: 10.3173
# Caractéristiques sélectionnées : [4, 7, 8, 10, 14, 21, 24, 25, 38, 41, 42, 55, 56, 59, 70, 75, 78, 79, 81, 86, 93, 99, 112, 122]
#
# Étape 61/100
# Récompense: 0.2020, Retour cumulé: 15.3190
# Caractéristiques sélectionnées : [4, 5, 6, 12, 19, 33, 34, 42, 45, 47, 49, 52, 57, 58, 59, 62, 65, 73, 77, 80, 83, 84, 87, 114]
#
# Étape 81/100
# Récompense: 0.2516, Retour cumulé: 20.2401
# Caractéristiques sélectionnées : [4, 14, 16, 19, 23, 27, 29, 35, 36, 37, 42, 60, 66, 67, 69, 80, 93, 98, 103, 107, 108, 110, 123, 125]
#
# Étape 100/100
# Récompense: 0.2379, Retour cumulé: 25.0240
# Caractéristiques sélectionnées : [1, 10, 14, 15, 17, 24, 25, 30, 32, 38, 55, 56, 57, 59, 60, 67, 68, 70, 79, 81, 93, 94, 99, 112, 114, 121, 122]
#
#
# Statistiques de l'épisode 14:
# Retour total: 25.0240
#
# ==================== Épisode 15/100 ====================
#
# Étape 1/100
# Récompense: 0.2739, Retour cumulé: 0.2739
# Caractéristiques sélectionnées : [8, 12, 13, 19, 27, 30, 37, 39, 42, 45, 52, 53, 54, 55, 56, 61, 63, 76, 81, 87, 88, 93, 95, 99, 106, 107, 108]
#
# Étape 21/100
# Récompense: 0.3019, Retour cumulé: 5.2802
# Caractéristiques sélectionnées : [0, 10, 14, 24, 25, 38, 40, 53, 55, 56, 59, 65, 70, 79, 81, 93, 95, 99, 112, 116, 122]
#
# Étape 41/100
# Récompense: 0.3268, Retour cumulé: 10.4965
# Caractéristiques sélectionnées : [0, 4, 10, 11, 20, 44, 47, 53, 60, 62, 73, 78, 79, 83, 84, 89, 90, 94, 99, 106, 112, 117, 122, 125]
#
# Étape 61/100
# Récompense: 0.2543, Retour cumulé: 15.8477
# Caractéristiques sélectionnées : [0, 2, 3, 10, 32, 42, 46, 47, 53, 62, 71, 73, 78, 79, 83, 84, 85, 90, 94, 99, 106, 112]
#
# Étape 81/100
# Récompense: 0.2064, Retour cumulé: 20.5408
# Caractéristiques sélectionnées : [0, 8, 9, 10, 19, 31, 32, 34, 37, 48, 52, 61, 63, 71, 76, 90, 93, 98, 109, 116, 125]
#
# Étape 100/100
# Récompense: 0.2828, Retour cumulé: 25.0471
# Caractéristiques sélectionnées : [1, 4, 12, 33, 34, 42, 47, 50, 53, 57, 58, 59, 61, 62, 65, 70, 72, 77, 80, 83, 87, 104, 106, 114, 117]
#
#
# Statistiques de l'épisode 15:
# Retour total: 25.0471
#
# ==================== Épisode 16/100 ====================
#
# Étape 1/100
# Récompense: 0.2376, Retour cumulé: 0.2376
# Caractéristiques sélectionnées : [8, 9, 32, 34, 36, 37, 42, 48, 52, 53, 56, 59, 61, 71, 76, 90, 93, 94, 98, 103, 109, 124, 125]
#
# Étape 21/100
# Récompense: 0.2965, Retour cumulé: 5.2730
# Caractéristiques sélectionnées : [3, 10, 14, 24, 25, 38, 39, 42, 46, 50, 55, 56, 59, 62, 70, 71, 75, 79, 81, 91, 93, 96, 99, 109, 112, 122]
#
# Étape 41/100
# Récompense: 0.2795, Retour cumulé: 10.4499
# Caractéristiques sélectionnées : [0, 3, 4, 5, 7, 9, 12, 18, 24, 29, 36, 39, 41, 52, 58, 60, 63, 78, 81, 88, 98, 102, 109, 112, 118, 123]
#
# Étape 61/100
# Récompense: 0.2665, Retour cumulé: 15.7613
# Caractéristiques sélectionnées : [8, 19, 37, 39, 42, 45, 53, 54, 55, 56, 61, 67, 84, 87, 89, 90, 95, 100, 106, 107, 108, 109, 110, 114, 121]
#
# Étape 81/100
# Récompense: 0.2330, Retour cumulé: 20.7033
# Caractéristiques sélectionnées : [6, 7, 16, 20, 25, 40, 42, 52, 61, 63, 67, 71, 74, 78, 85, 90, 93, 95, 102, 110, 111, 117, 120, 122, 123, 124]
#
# Étape 100/100
# Récompense: 0.2906, Retour cumulé: 25.4903
# Caractéristiques sélectionnées : [0, 4, 5, 7, 12, 16, 32, 38, 51, 52, 58, 60, 63, 75, 78, 81, 99, 102, 109, 112, 114, 120, 123]
#
#
# Statistiques de l'épisode 16:
# Retour total: 25.4903
#
# ==================== Épisode 17/100 ====================
#
# Étape 1/100
# Récompense: 0.2853, Retour cumulé: 0.2853
# Caractéristiques sélectionnées : [4, 12, 29, 33, 34, 42, 45, 47, 55, 57, 58, 59, 60, 62, 69, 77, 80, 83, 84, 87, 114, 117, 119, 125, 126]
#
# Étape 21/100
# Récompense: 0.2161, Retour cumulé: 5.4179
# Caractéristiques sélectionnées : [13, 15, 19, 23, 37, 39, 42, 45, 49, 50, 53, 54, 55, 56, 61, 71, 78, 87, 89, 95, 106, 107, 108, 120, 126]
#
# Étape 41/100
# Récompense: 0.2443, Retour cumulé: 10.3539
# Caractéristiques sélectionnées : [0, 19, 22, 29, 37, 39, 42, 45, 53, 54, 55, 56, 61, 77, 86, 87, 95, 106, 107, 108, 119, 125]
#
# Étape 61/100
# Récompense: 0.2845, Retour cumulé: 15.5588
# Caractéristiques sélectionnées : [9, 10, 14, 22, 24, 25, 38, 39, 54, 55, 56, 59, 69, 70, 76, 79, 81, 86, 93, 95, 99, 103, 112, 122]
#
# Étape 81/100
# Récompense: 0.2547, Retour cumulé: 20.8574
# Caractéristiques sélectionnées : [0, 4, 5, 7, 12, 17, 33, 36, 51, 52, 58, 60, 61, 63, 78, 81, 91, 95, 102, 107, 109, 112, 114, 116, 123]
#
# Étape 100/100
# Récompense: 0.1896, Retour cumulé: 25.7328
# Caractéristiques sélectionnées : [8, 9, 13, 15, 32, 34, 37, 48, 52, 53, 61, 71, 76, 90, 93, 98, 101, 109, 114, 116, 125, 126]
#
#
# Statistiques de l'épisode 17:
# Retour total: 25.7328
#
# ==================== Épisode 18/100 ====================
#
# Étape 1/100
# Récompense: 0.3095, Retour cumulé: 0.3095
# Caractéristiques sélectionnées : [14, 16, 19, 21, 22, 23, 27, 29, 31, 35, 37, 38, 41, 42, 60, 69, 82, 93, 98, 106, 107, 112, 120, 125]
#
# Étape 21/100
# Récompense: 0.2300, Retour cumulé: 5.4768
# Caractéristiques sélectionnées : [0, 4, 10, 32, 47, 53, 62, 72, 73, 78, 79, 83, 84, 89, 90, 94, 99, 106, 112, 120]
#
# Étape 41/100
# Récompense: 0.1981, Retour cumulé: 10.9826
# Caractéristiques sélectionnées : [0, 6, 7, 14, 20, 30, 34, 40, 52, 60, 61, 62, 79, 91, 98, 100, 102, 109, 111, 114, 121, 125, 126, 127]
#
# Étape 61/100
# Récompense: 0.2853, Retour cumulé: 16.2279
# Caractéristiques sélectionnées : [9, 10, 14, 19, 24, 25, 31, 38, 41, 47, 49, 50, 55, 56, 59, 70, 71, 79, 81, 93, 99, 112, 122]
#
# Étape 81/100
# Récompense: 0.3907, Retour cumulé: 22.1634
# Caractéristiques sélectionnées : [2, 3, 10, 14, 22, 24, 25, 26, 38, 39, 55, 56, 59, 70, 79, 81, 82, 93, 99, 110, 112, 122, 125, 127]
#
# Étape 100/100
# Récompense: 0.2123, Retour cumulé: 27.2210
# Caractéristiques sélectionnées : [4, 5, 12, 25, 33, 34, 42, 47, 57, 58, 59, 60, 61, 62, 71, 77, 80, 83, 87, 89, 94, 101, 114, 121, 124]
#
#
# Statistiques de l'épisode 18:
# Retour total: 27.2210
#
# ==================== Épisode 19/100 ====================
#
# Étape 1/100
# Récompense: 0.2761, Retour cumulé: 0.2761
# Caractéristiques sélectionnées : [0, 4, 5, 7, 11, 12, 17, 20, 46, 48, 50, 52, 58, 60, 63, 78, 81, 83, 90, 102, 106, 109, 112, 119, 123]
#
# Étape 21/100
# Récompense: 0.2761, Retour cumulé: 5.4667
# Caractéristiques sélectionnées : [19, 37, 39, 42, 45, 48, 49, 53, 54, 55, 56, 61, 62, 69, 85, 87, 94, 95, 98, 106, 107, 108, 122, 125]
#
# Étape 41/100
# Récompense: 0.3089, Retour cumulé: 11.1507
# Caractéristiques sélectionnées : [0, 5, 6, 7, 9, 11, 13, 20, 25, 34, 40, 60, 61, 77, 79, 100, 102, 109, 111, 114, 125, 126, 127]
#
# Étape 61/100
# Récompense: 0.3033, Retour cumulé: 16.5792
# Caractéristiques sélectionnées : [7, 8, 9, 17, 32, 34, 37, 48, 52, 61, 71, 76, 79, 90, 93, 94, 96, 98, 109, 111, 122, 125]
#
# Étape 81/100
# Récompense: 0.3006, Retour cumulé: 21.7670
# Caractéristiques sélectionnées : [8, 10, 14, 18, 24, 25, 38, 41, 48, 49, 55, 56, 59, 63, 70, 76, 79, 81, 86, 93, 99, 105, 112, 122]
#
# Étape 100/100
# Récompense: 0.2373, Retour cumulé: 26.6082
# Caractéristiques sélectionnées : [0, 1, 4, 5, 7, 12, 13, 21, 38, 41, 43, 52, 58, 60, 63, 70, 78, 81, 102, 109, 110, 112, 115, 123]
#
#
# Statistiques de l'épisode 19:
# Retour total: 26.6082
#
# ==================== Épisode 20/100 ====================
#
# Étape 1/100
# Récompense: 0.2360, Retour cumulé: 0.2360
# Caractéristiques sélectionnées : [2, 7, 15, 19, 23, 28, 31, 34, 42, 49, 53, 60, 68, 69, 73, 93, 110, 114, 115, 117, 119, 125, 126, 127]
#
# Étape 21/100
# Récompense: 0.2558, Retour cumulé: 5.6406
# Caractéristiques sélectionnées : [0, 8, 10, 15, 34, 47, 53, 62, 73, 78, 79, 80, 83, 84, 87, 90, 94, 95, 99, 106, 112, 116, 118, 125]
#
# Étape 41/100
# Récompense: 0.2391, Retour cumulé: 11.0501
# Caractéristiques sélectionnées : [6, 8, 9, 19, 32, 34, 35, 37, 47, 48, 49, 51, 52, 61, 71, 76, 90, 93, 98, 109, 114, 124, 125]
#
# Étape 61/100
# Récompense: 0.3102, Retour cumulé: 16.3938
# Caractéristiques sélectionnées : [0, 4, 10, 16, 25, 39, 40, 43, 47, 53, 62, 71, 73, 74, 76, 78, 79, 83, 84, 90, 94, 99, 106, 112]
#
# Étape 81/100
# Récompense: 0.2927, Retour cumulé: 21.6987
# Caractéristiques sélectionnées : [4, 12, 16, 33, 34, 41, 42, 47, 50, 57, 58, 59, 62, 65, 77, 80, 83, 85, 87, 100, 102, 114, 125]
#
# Étape 100/100
# Récompense: 0.3247, Retour cumulé: 27.1573
# Caractéristiques sélectionnées : [0, 6, 14, 15, 16, 19, 23, 27, 29, 31, 35, 37, 42, 43, 49, 54, 60, 69, 93, 98, 102, 107, 109, 125]
#
#
# Statistiques de l'épisode 20:
# Retour total: 27.1573
#
# ==================== Épisode 21/100 ====================
#
# Étape 1/100
# Récompense: 0.2848, Retour cumulé: 0.2848
# Caractéristiques sélectionnées : [3, 14, 16, 19, 23, 27, 29, 35, 37, 42, 46, 53, 55, 60, 68, 69, 78, 92, 93, 95, 97, 98, 99, 107, 125]
#
# Étape 21/100
# Récompense: 0.3226, Retour cumulé: 5.7633
# Caractéristiques sélectionnées : [8, 9, 20, 32, 34, 37, 48, 52, 61, 66, 71, 74, 76, 84, 90, 91, 93, 94, 98, 101, 109, 118, 125, 127]
#
# Étape 41/100
# Récompense: 0.2780, Retour cumulé: 11.4362
# Caractéristiques sélectionnées : [14, 16, 19, 23, 27, 29, 34, 35, 37, 42, 55, 57, 60, 69, 85, 92, 93, 94, 98, 107, 116, 124, 125]
#
# Étape 61/100
# Récompense: 0.2996, Retour cumulé: 17.1615
# Caractéristiques sélectionnées : [6, 7, 8, 16, 20, 24, 25, 27, 29, 42, 48, 52, 67, 70, 78, 85, 95, 102, 106, 111, 120, 124]
#
# Étape 81/100
# Récompense: 0.1988, Retour cumulé: 22.6577
# Caractéristiques sélectionnées : [0, 6, 7, 10, 20, 21, 34, 39, 40, 50, 56, 58, 77, 79, 81, 100, 102, 104, 105, 109, 111, 114, 125, 126, 127]
#
# Étape 100/100
# Récompense: 0.2001, Retour cumulé: 27.9181
# Caractéristiques sélectionnées : [1, 14, 16, 19, 23, 27, 29, 35, 37, 42, 44, 46, 53, 60, 67, 69, 79, 93, 98, 104, 106, 107, 115, 116, 125]
#
#
# Statistiques de l'épisode 21:
# Retour total: 27.9181
#
# ==================== Épisode 22/100 ====================
#
# Étape 1/100
# Récompense: 0.2996, Retour cumulé: 0.2996
# Caractéristiques sélectionnées : [0, 1, 3, 4, 5, 7, 8, 9, 12, 35, 52, 58, 60, 63, 77, 78, 81, 86, 97, 102, 109, 112, 123]
#
# Étape 21/100
# Récompense: 0.2581, Retour cumulé: 6.2725
# Caractéristiques sélectionnées : [0, 4, 10, 31, 40, 47, 53, 60, 62, 64, 68, 73, 78, 79, 80, 83, 84, 90, 91, 94, 95, 99, 106, 112, 116, 124]
#
# Étape 41/100
# Récompense: 0.2514, Retour cumulé: 12.0782
# Caractéristiques sélectionnées : [6, 7, 16, 20, 23, 25, 42, 52, 56, 67, 72, 75, 76, 78, 84, 85, 86, 95, 102, 110, 111, 120, 124]
#
# Étape 61/100
# Récompense: 0.3280, Retour cumulé: 17.7899
# Caractéristiques sélectionnées : [17, 19, 37, 39, 42, 45, 53, 54, 55, 56, 61, 77, 78, 86, 87, 92, 95, 106, 107, 108, 119, 120]
#
# Étape 81/100
# Récompense: 0.3423, Retour cumulé: 23.5463
# Caractéristiques sélectionnées : [10, 14, 24, 25, 27, 38, 45, 55, 56, 59, 65, 70, 79, 81, 84, 92, 93, 95, 99, 112, 119, 120, 122]
#
# Étape 100/100
# Récompense: 0.2448, Retour cumulé: 28.8186
# Caractéristiques sélectionnées : [0, 10, 19, 33, 47, 53, 62, 63, 73, 74, 77, 78, 79, 83, 84, 90, 92, 94, 99, 100, 105, 106, 112, 114, 125]
#
#
# Statistiques de l'épisode 22:
# Retour total: 28.8186
#
# ==================== Épisode 23/100 ====================
#
# Étape 1/100
# Récompense: 0.2389, Retour cumulé: 0.2389
# Caractéristiques sélectionnées : [0, 6, 7, 13, 17, 20, 29, 32, 34, 40, 57, 64, 69, 79, 88, 100, 102, 109, 111, 114, 123, 124, 125, 126, 127]
#
# Étape 21/100
# Récompense: 0.2887, Retour cumulé: 5.9661
# Caractéristiques sélectionnées : [8, 9, 10, 24, 29, 32, 34, 37, 40, 48, 50, 52, 61, 68, 70, 71, 76, 78, 81, 90, 91, 93, 95, 98, 109, 112, 125]
#
# Étape 41/100
# Récompense: 0.2778, Retour cumulé: 12.0363
# Caractéristiques sélectionnées : [0, 10, 36, 38, 46, 47, 53, 58, 62, 72, 73, 78, 79, 83, 84, 90, 91, 94, 99, 105, 106, 109, 112]
#
# Étape 61/100
# Récompense: 0.1732, Retour cumulé: 17.3418
# Caractéristiques sélectionnées : [14, 16, 19, 23, 27, 29, 35, 37, 42, 44, 52, 60, 61, 62, 69, 75, 89, 92, 93, 98, 101, 107, 117, 123, 125]
#
# Étape 81/100
# Récompense: 0.3594, Retour cumulé: 23.1925
# Caractéristiques sélectionnées : [8, 9, 16, 19, 37, 38, 39, 42, 45, 48, 53, 54, 55, 56, 61, 62, 87, 95, 106, 107, 108, 124]
#
# Étape 100/100
# Récompense: 0.3195, Retour cumulé: 28.7907
# Caractéristiques sélectionnées : [0, 10, 35, 40, 42, 47, 49, 53, 55, 56, 57, 60, 62, 73, 78, 79, 83, 84, 89, 90, 94, 99, 106, 112]
#
#
# Statistiques de l'épisode 23:
# Retour total: 28.7907
#
# ==================== Épisode 24/100 ====================
#
# Étape 1/100
# Récompense: 0.2959, Retour cumulé: 0.2959
# Caractéristiques sélectionnées : [14, 16, 19, 23, 27, 29, 31, 35, 36, 37, 42, 59, 60, 69, 70, 74, 78, 93, 98, 107, 111, 112, 125]
#
# Étape 21/100
# Récompense: 0.2982, Retour cumulé: 5.9957
# Caractéristiques sélectionnées : [4, 8, 19, 37, 39, 42, 44, 45, 49, 53, 54, 55, 56, 61, 68, 73, 81, 85, 87, 88, 90, 95, 106, 107, 108, 115]
#
# Étape 41/100
# Récompense: 0.2843, Retour cumulé: 11.8747
# Caractéristiques sélectionnées : [4, 7, 12, 33, 34, 42, 47, 48, 57, 58, 59, 62, 67, 71, 77, 80, 81, 83, 87, 88, 105, 114]
#
# Étape 61/100
# Récompense: 0.4354, Retour cumulé: 17.9760
# Caractéristiques sélectionnées : [2, 4, 12, 17, 22, 26, 31, 33, 34, 38, 42, 47, 51, 57, 58, 59, 62, 66, 77, 80, 83, 87, 114, 116, 118]
#
# Étape 81/100
# Récompense: 0.3300, Retour cumulé: 24.2788
# Caractéristiques sélectionnées : [0, 1, 5, 6, 7, 9, 20, 34, 40, 43, 45, 78, 79, 81, 87, 100, 102, 109, 111, 114, 125, 126, 127]
#
# Étape 100/100
# Récompense: 0.2437, Retour cumulé: 29.6482
# Caractéristiques sélectionnées : [0, 2, 14, 16, 19, 21, 23, 26, 27, 28, 29, 35, 37, 42, 60, 69, 83, 92, 93, 95, 98, 106, 107, 125, 127]
#
#
# Statistiques de l'épisode 24:
# Retour total: 29.6482
#
# ==================== Épisode 25/100 ====================
#
# Étape 1/100
# Récompense: 0.2693, Retour cumulé: 0.2693
# Caractéristiques sélectionnées : [7, 8, 9, 32, 34, 37, 44, 48, 51, 52, 61, 71, 75, 76, 85, 90, 93, 97, 98, 100, 109, 119, 125]
#
# Étape 21/100
# Récompense: 0.4105, Retour cumulé: 6.3370
# Caractéristiques sélectionnées : [2, 6, 10, 14, 15, 24, 25, 26, 38, 41, 44, 55, 56, 59, 70, 79, 81, 93, 99, 105, 111, 112, 116, 122, 123]
#
# Étape 41/100
# Récompense: 0.3048, Retour cumulé: 12.2683
# Caractéristiques sélectionnées : [0, 4, 5, 7, 10, 12, 43, 45, 50, 52, 54, 58, 60, 63, 68, 71, 78, 81, 89, 99, 102, 109, 112, 121, 123]
#
# Étape 61/100
# Récompense: 0.3076, Retour cumulé: 18.1483
# Caractéristiques sélectionnées : [3, 19, 37, 38, 39, 42, 45, 51, 53, 54, 55, 56, 61, 76, 87, 95, 106, 107, 108, 117, 120]
#
# Étape 81/100
# Récompense: 0.2705, Retour cumulé: 23.9415
# Caractéristiques sélectionnées : [0, 6, 7, 13, 20, 25, 34, 37, 40, 50, 61, 79, 100, 102, 109, 111, 114, 119, 120, 125, 126, 127]
#
# Étape 100/100
# Récompense: 0.3224, Retour cumulé: 29.2997
# Caractéristiques sélectionnées : [0, 6, 7, 8, 14, 20, 22, 31, 34, 40, 42, 47, 57, 69, 79, 83, 87, 99, 100, 102, 109, 111, 114, 125, 126, 127]
#
#
# Statistiques de l'épisode 25:
# Retour total: 29.2997
#
# ==================== Épisode 26/100 ====================
#
# Étape 1/100
# Récompense: 0.2652, Retour cumulé: 0.2652
# Caractéristiques sélectionnées : [0, 1, 7, 8, 10, 15, 27, 29, 47, 50, 53, 54, 55, 62, 73, 78, 79, 83, 84, 85, 90, 94, 99, 106, 112]
#
# Étape 21/100
# Récompense: 0.2975, Retour cumulé: 6.6111
# Caractéristiques sélectionnées : [1, 10, 14, 24, 25, 35, 38, 47, 50, 55, 56, 59, 70, 79, 81, 86, 93, 96, 99, 111, 112, 122]
#
# Étape 41/100
# Récompense: 0.2811, Retour cumulé: 12.6517
# Caractéristiques sélectionnées : [8, 9, 12, 15, 16, 18, 31, 32, 34, 37, 48, 52, 61, 71, 72, 76, 90, 92, 93, 98, 109, 122, 125]
#
# Étape 61/100
# Récompense: 0.2479, Retour cumulé: 18.5454
# Caractéristiques sélectionnées : [1, 10, 11, 14, 24, 25, 26, 38, 49, 55, 56, 59, 62, 70, 79, 81, 93, 99, 101, 104, 112, 122]
#
# Étape 81/100
# Récompense: 0.2849, Retour cumulé: 24.5481
# Caractéristiques sélectionnées : [14, 16, 19, 23, 27, 29, 35, 37, 42, 45, 48, 60, 65, 69, 71, 78, 84, 88, 93, 98, 107, 113, 125]
#
# Étape 100/100
# Récompense: 0.3884, Retour cumulé: 30.4219
# Caractéristiques sélectionnées : [0, 4, 5, 7, 12, 35, 39, 43, 52, 58, 60, 63, 76, 78, 81, 82, 90, 94, 102, 109, 112, 116, 123, 127]
#
#
# Statistiques de l'épisode 26:
# Retour total: 30.4219
#
# ==================== Épisode 27/100 ====================
#
# Étape 1/100
# Récompense: 0.3714, Retour cumulé: 0.3714
# Caractéristiques sélectionnées : [0, 4, 5, 7, 12, 15, 29, 47, 52, 55, 58, 59, 60, 63, 78, 81, 99, 100, 101, 102, 109, 112, 123]
#
# Étape 21/100
# Récompense: 0.3462, Retour cumulé: 7.0356
# Caractéristiques sélectionnées : [2, 4, 19, 28, 37, 39, 40, 42, 45, 47, 52, 53, 54, 55, 56, 61, 80, 87, 95, 97, 106, 107, 108]
#
# Étape 41/100
# Récompense: 0.2647, Retour cumulé: 12.9928
# Caractéristiques sélectionnées : [9, 10, 14, 15, 24, 25, 38, 55, 56, 59, 69, 70, 73, 74, 79, 81, 93, 99, 108, 112, 120, 122]
#
# Étape 61/100
# Récompense: 0.3530, Retour cumulé: 18.9259
# Caractéristiques sélectionnées : [3, 10, 14, 24, 25, 27, 38, 42, 55, 56, 58, 59, 70, 76, 79, 81, 93, 99, 101, 112, 117, 120, 122]
#
# Étape 81/100
# Récompense: 0.2772, Retour cumulé: 25.1891
# Caractéristiques sélectionnées : [3, 8, 9, 11, 12, 32, 33, 34, 37, 47, 48, 52, 61, 62, 67, 71, 76, 87, 90, 93, 98, 109, 125]
#
# Étape 100/100
# Récompense: 0.3197, Retour cumulé: 31.2815
# Caractéristiques sélectionnées : [0, 2, 8, 9, 12, 15, 32, 34, 37, 45, 47, 48, 52, 61, 71, 76, 87, 90, 93, 96, 98, 103, 107, 109, 125]
#
#
# Statistiques de l'épisode 27:
# Retour total: 31.2815
#
# ==================== Épisode 28/100 ====================
#
# Étape 1/100
# Récompense: 0.3409, Retour cumulé: 0.3409
# Caractéristiques sélectionnées : [8, 9, 32, 34, 35, 37, 48, 52, 53, 54, 61, 63, 66, 71, 76, 90, 93, 95, 98, 109, 111, 125]
#
# Étape 21/100
# Récompense: 0.3408, Retour cumulé: 6.4268
# Caractéristiques sélectionnées : [8, 14, 16, 19, 23, 27, 29, 31, 35, 37, 42, 47, 50, 60, 64, 68, 69, 71, 93, 98, 107, 111, 125]
#
# Étape 41/100
# Récompense: 0.3041, Retour cumulé: 12.6223
# Caractéristiques sélectionnées : [19, 20, 37, 39, 41, 42, 45, 47, 53, 54, 55, 56, 57, 61, 84, 86, 87, 95, 99, 106, 107, 108, 111, 113]
#
# Étape 61/100
# Récompense: 0.2750, Retour cumulé: 18.7608
# Caractéristiques sélectionnées : [0, 2, 4, 5, 12, 22, 33, 34, 42, 44, 47, 57, 58, 59, 62, 77, 80, 83, 87, 88, 108, 114, 122]
#
# Étape 81/100
# Récompense: 0.3007, Retour cumulé: 24.8593
# Caractéristiques sélectionnées : [0, 2, 5, 10, 24, 35, 36, 43, 47, 53, 62, 63, 69, 73, 78, 79, 83, 84, 90, 94, 99, 106, 112, 125]
#
# Étape 100/100
# Récompense: 0.3117, Retour cumulé: 30.6463
# Caractéristiques sélectionnées : [0, 2, 4, 19, 35, 37, 39, 42, 43, 45, 53, 54, 55, 56, 61, 87, 88, 90, 95, 97, 105, 106, 107, 108, 123]
#
#
# Statistiques de l'épisode 28:
# Retour total: 30.6463
#
# ==================== Épisode 29/100 ====================
#
# Étape 1/100
# Récompense: 0.2904, Retour cumulé: 0.2904
# Caractéristiques sélectionnées : [10, 14, 24, 25, 33, 38, 47, 50, 54, 55, 56, 59, 61, 69, 70, 79, 81, 91, 93, 99, 112, 122, 126, 127]
#
# Étape 21/100
# Récompense: 0.3526, Retour cumulé: 6.6431
# Caractéristiques sélectionnées : [19, 25, 37, 39, 42, 45, 50, 52, 53, 54, 55, 56, 61, 70, 78, 79, 87, 93, 95, 106, 107, 108, 126]
#
# Étape 41/100
# Récompense: 0.3518, Retour cumulé: 13.1358
# Caractéristiques sélectionnées : [0, 1, 4, 5, 7, 12, 52, 57, 58, 60, 63, 67, 76, 78, 81, 85, 102, 107, 109, 111, 112, 121, 123]
#
# Étape 61/100
# Récompense: 0.2100, Retour cumulé: 19.5277
# Caractéristiques sélectionnées : [2, 14, 16, 19, 23, 27, 29, 31, 35, 37, 38, 42, 60, 65, 69, 74, 83, 93, 98, 101, 103, 105, 107, 114, 117, 125]
#
# Étape 81/100
# Récompense: 0.3157, Retour cumulé: 25.5837
# Caractéristiques sélectionnées : [2, 6, 7, 16, 20, 25, 26, 42, 47, 52, 61, 66, 67, 78, 80, 85, 95, 102, 107, 111, 114, 120, 124]
#
# Étape 100/100
# Récompense: 0.2904, Retour cumulé: 31.3793
# Caractéristiques sélectionnées : [14, 16, 19, 23, 25, 27, 29, 35, 37, 42, 44, 52, 57, 60, 69, 72, 76, 93, 98, 102, 107, 125, 127]
#
#
# Statistiques de l'épisode 29:
# Retour total: 31.3793
#
# ==================== Épisode 30/100 ====================
#
# Étape 1/100
# Récompense: 0.3721, Retour cumulé: 0.3721
# Caractéristiques sélectionnées : [11, 15, 23, 28, 31, 38, 39, 42, 45, 51, 58, 59, 60, 65, 66, 68, 69, 93, 110, 115, 117, 119, 123, 125, 127]
#
# Étape 21/100
# Récompense: 0.2770, Retour cumulé: 6.5334
# Caractéristiques sélectionnées : [4, 12, 26, 30, 31, 33, 34, 42, 47, 57, 58, 59, 62, 71, 75, 77, 79, 80, 83, 87, 92, 109, 111, 114, 118]
#
# Étape 41/100
# Récompense: 0.3313, Retour cumulé: 12.6552
# Caractéristiques sélectionnées : [6, 7, 16, 20, 25, 33, 42, 52, 58, 63, 67, 78, 84, 85, 94, 95, 102, 111, 114, 120, 124, 125]
#
# Étape 61/100
# Récompense: 0.3596, Retour cumulé: 18.9531
# Caractéristiques sélectionnées : [0, 6, 7, 10, 16, 20, 25, 42, 52, 54, 66, 67, 73, 78, 85, 95, 102, 109, 111, 120, 124]
#
# Étape 81/100
# Récompense: 0.3388, Retour cumulé: 25.0951
# Caractéristiques sélectionnées : [0, 4, 5, 7, 12, 13, 15, 19, 38, 52, 58, 60, 63, 67, 76, 78, 81, 102, 107, 109, 112, 120, 123]
#
# Étape 100/100
# Récompense: 0.2900, Retour cumulé: 31.1820
# Caractéristiques sélectionnées : [6, 7, 16, 17, 20, 21, 25, 36, 42, 43, 52, 67, 78, 85, 95, 101, 102, 111, 117, 120, 122, 124, 127]
#
#
# Statistiques de l'épisode 30:
# Retour total: 31.1820
#
# ==================== Épisode 31/100 ====================
#
# Étape 1/100
# Récompense: 0.3225, Retour cumulé: 0.3225
# Caractéristiques sélectionnées : [15, 18, 22, 23, 26, 27, 28, 31, 42, 59, 60, 66, 68, 69, 85, 93, 96, 110, 115, 117, 119, 125, 127]
#
# Étape 21/100
# Récompense: 0.2395, Retour cumulé: 6.8211
# Caractéristiques sélectionnées : [10, 14, 16, 23, 24, 25, 30, 38, 54, 55, 56, 59, 70, 71, 79, 81, 90, 93, 99, 110, 112, 122]
#
# Étape 41/100
# Récompense: 0.2804, Retour cumulé: 13.2340
# Caractéristiques sélectionnées : [0, 3, 10, 20, 47, 52, 53, 62, 67, 73, 78, 79, 80, 83, 84, 87, 90, 94, 99, 102, 106, 110, 112, 116]
#
# Étape 61/100
# Récompense: 0.3451, Retour cumulé: 20.0224
# Caractéristiques sélectionnées : [6, 7, 14, 16, 20, 21, 25, 42, 44, 52, 55, 59, 61, 66, 67, 70, 78, 83, 85, 87, 95, 102, 111, 117, 120, 124]
#
# Étape 81/100
# Récompense: 0.3497, Retour cumulé: 26.2779
# Caractéristiques sélectionnées : [0, 10, 11, 20, 28, 31, 42, 47, 53, 62, 73, 78, 79, 83, 84, 90, 94, 99, 106, 109, 110, 112, 113, 115]
#
# Étape 100/100
# Récompense: 0.3251, Retour cumulé: 32.4306
# Caractéristiques sélectionnées : [15, 23, 28, 31, 39, 42, 50, 60, 68, 69, 73, 87, 92, 93, 99, 110, 115, 117, 119, 124, 125, 127]
#
#
# Statistiques de l'épisode 31:
# Retour total: 32.4306
#
# ==================== Épisode 32/100 ====================
#
# Étape 1/100
# Récompense: 0.3741, Retour cumulé: 0.3741
# Caractéristiques sélectionnées : [6, 7, 8, 16, 20, 25, 42, 48, 49, 52, 67, 74, 78, 85, 95, 102, 106, 111, 120, 123, 124]
#
# Étape 21/100
# Récompense: 0.3185, Retour cumulé: 6.7668
# Caractéristiques sélectionnées : [2, 4, 6, 7, 15, 16, 20, 22, 25, 42, 47, 52, 59, 67, 78, 85, 95, 102, 111, 120, 124]
#
# Étape 41/100
# Récompense: 0.3233, Retour cumulé: 13.2172
# Caractéristiques sélectionnées : [0, 15, 23, 28, 31, 34, 38, 42, 44, 60, 63, 68, 69, 93, 94, 103, 106, 110, 113, 115, 117, 119, 124, 125, 126, 127]
#
# Étape 61/100
# Récompense: 0.3337, Retour cumulé: 19.8776
# Caractéristiques sélectionnées : [0, 10, 18, 23, 28, 46, 47, 49, 53, 57, 62, 71, 73, 78, 79, 83, 84, 90, 94, 97, 99, 106, 112, 114, 122, 127]
#
# Étape 81/100
# Récompense: 0.3904, Retour cumulé: 26.5951
# Caractéristiques sélectionnées : [0, 8, 19, 28, 30, 37, 39, 42, 45, 53, 54, 55, 56, 58, 61, 70, 76, 87, 95, 103, 106, 107, 108, 109]
#
# Étape 100/100
# Récompense: 0.3424, Retour cumulé: 33.0815
# Caractéristiques sélectionnées : [2, 6, 14, 16, 19, 23, 27, 29, 35, 37, 42, 56, 60, 69, 70, 77, 89, 93, 98, 105, 107, 108, 122, 125]
#
#
# Statistiques de l'épisode 32:
# Retour total: 33.0815
#
# ==================== Épisode 33/100 ====================
#
# Étape 1/100
# Récompense: 0.2912, Retour cumulé: 0.2912
# Caractéristiques sélectionnées : [6, 7, 16, 17, 19, 20, 25, 31, 42, 47, 52, 54, 67, 68, 78, 83, 85, 95, 100, 102, 107, 111, 120, 124, 125, 127]
#
# Étape 21/100
# Récompense: 0.3012, Retour cumulé: 7.2131
# Caractéristiques sélectionnées : [13, 15, 19, 22, 23, 37, 39, 42, 45, 51, 53, 54, 55, 56, 61, 80, 87, 95, 101, 106, 107, 108, 110]
#
# Étape 41/100
# Récompense: 0.3744, Retour cumulé: 13.8964
# Caractéristiques sélectionnées : [0, 6, 7, 20, 24, 30, 34, 36, 37, 40, 59, 79, 83, 95, 99, 100, 102, 107, 109, 111, 113, 114, 121, 125, 126, 127]
#
# Étape 61/100
# Récompense: 0.3880, Retour cumulé: 20.6261
# Caractéristiques sélectionnées : [14, 16, 19, 21, 23, 27, 29, 33, 34, 35, 36, 37, 42, 56, 60, 63, 69, 72, 74, 87, 90, 93, 98, 107, 125]
#
# Étape 81/100
# Récompense: 0.3801, Retour cumulé: 26.9502
# Caractéristiques sélectionnées : [3, 6, 15, 23, 27, 28, 30, 31, 34, 42, 60, 68, 69, 73, 81, 93, 94, 110, 113, 115, 117, 119, 125, 127]
#
# Étape 100/100
# Récompense: 0.3272, Retour cumulé: 33.4695
# Caractéristiques sélectionnées : [0, 10, 23, 47, 49, 53, 62, 63, 73, 78, 79, 83, 84, 90, 94, 98, 99, 106, 112, 120, 123]
#
#
# Statistiques de l'épisode 33:
# Retour total: 33.4695
#
# ==================== Épisode 34/100 ====================
#
# Étape 1/100
# Récompense: 0.3089, Retour cumulé: 0.3089
# Caractéristiques sélectionnées : [0, 10, 18, 23, 40, 45, 47, 49, 53, 57, 62, 73, 78, 79, 83, 84, 90, 94, 99, 102, 106, 112, 118, 121, 124]
#
# Étape 21/100
# Récompense: 0.3528, Retour cumulé: 7.2024
# Caractéristiques sélectionnées : [5, 14, 16, 19, 21, 23, 27, 29, 33, 35, 37, 42, 54, 60, 69, 76, 85, 93, 98, 107, 110, 120, 125]
#
# Étape 41/100
# Récompense: 0.3367, Retour cumulé: 13.9649
# Caractéristiques sélectionnées : [2, 4, 13, 19, 26, 32, 37, 39, 42, 45, 53, 54, 55, 56, 61, 67, 78, 79, 81, 85, 87, 95, 103, 106, 107, 108, 114]
#
# Étape 61/100
# Récompense: 0.3634, Retour cumulé: 20.6733
# Caractéristiques sélectionnées : [7, 15, 23, 28, 30, 31, 40, 42, 47, 48, 52, 58, 60, 68, 69, 70, 92, 93, 94, 110, 115, 117, 119, 125, 127]
#
# Étape 81/100
# Récompense: 0.3436, Retour cumulé: 27.2507
# Caractéristiques sélectionnées : [8, 15, 23, 26, 28, 31, 42, 49, 60, 65, 68, 69, 71, 73, 77, 93, 97, 110, 115, 117, 119, 125, 127]
#
# Étape 100/100
# Récompense: 0.3467, Retour cumulé: 33.6502
# Caractéristiques sélectionnées : [14, 16, 19, 20, 23, 27, 29, 34, 35, 36, 37, 42, 60, 69, 74, 80, 81, 93, 98, 107, 120, 121, 125]
#
#
# Statistiques de l'épisode 34:
# Retour total: 33.6502
#
# ==================== Épisode 35/100 ====================
#
# Étape 1/100
# Récompense: 0.3166, Retour cumulé: 0.3166
# Caractéristiques sélectionnées : [0, 4, 5, 7, 12, 33, 52, 58, 60, 63, 68, 78, 81, 90, 95, 98, 102, 105, 108, 109, 112, 123, 124]
#
# Étape 21/100
# Récompense: 0.3315, Retour cumulé: 7.0177
# Caractéristiques sélectionnées : [0, 1, 11, 19, 37, 39, 42, 45, 48, 53, 54, 55, 56, 61, 80, 85, 87, 90, 95, 106, 107, 108, 113]
#
# Étape 41/100
# Récompense: 0.4000, Retour cumulé: 13.6787
# Caractéristiques sélectionnées : [7, 14, 19, 27, 31, 32, 37, 39, 42, 45, 53, 54, 55, 56, 61, 79, 87, 95, 101, 106, 107, 108, 110, 112, 126]
#
# Étape 61/100
# Récompense: 0.3575, Retour cumulé: 20.2800
# Caractéristiques sélectionnées : [1, 3, 8, 9, 15, 25, 32, 34, 37, 42, 44, 48, 52, 61, 69, 71, 76, 89, 90, 92, 93, 98, 103, 109, 125]
#
# Étape 81/100
# Récompense: 0.3111, Retour cumulé: 26.2879
# Caractéristiques sélectionnées : [4, 12, 21, 27, 28, 32, 33, 34, 42, 47, 55, 57, 58, 59, 61, 62, 66, 77, 80, 83, 87, 102, 103, 111, 114]
#
# Étape 100/100
# Récompense: 0.3531, Retour cumulé: 32.5851
# Caractéristiques sélectionnées : [0, 6, 7, 16, 20, 33, 34, 40, 59, 62, 66, 74, 75, 76, 77, 79, 87, 90, 100, 102, 109, 111, 114, 125, 126, 127]
#
#
# Statistiques de l'épisode 35:
# Retour total: 32.5851
#
# ==================== Épisode 36/100 ====================
#
# Étape 1/100
# Récompense: 0.3426, Retour cumulé: 0.3426
# Caractéristiques sélectionnées : [2, 19, 34, 37, 39, 42, 45, 53, 54, 55, 56, 60, 61, 65, 75, 87, 95, 103, 106, 107, 108, 112]
#
# Étape 21/100
# Récompense: 0.3388, Retour cumulé: 6.9620
# Caractéristiques sélectionnées : [6, 7, 14, 15, 16, 20, 25, 37, 38, 40, 42, 47, 52, 67, 78, 85, 91, 95, 97, 102, 110, 111, 118, 120, 124, 127]
#
# Étape 41/100
# Récompense: 0.3653, Retour cumulé: 13.7861
# Caractéristiques sélectionnées : [0, 6, 7, 17, 19, 20, 34, 35, 40, 49, 53, 79, 94, 100, 102, 109, 111, 114, 121, 125, 126, 127]
#
# Étape 61/100
# Récompense: 0.2865, Retour cumulé: 20.7133
# Caractéristiques sélectionnées : [0, 4, 6, 7, 10, 20, 34, 37, 40, 54, 61, 71, 79, 80, 83, 84, 86, 92, 100, 102, 106, 109, 111, 114, 125, 126, 127]
#
# Étape 81/100
# Récompense: 0.4301, Retour cumulé: 27.9432
# Caractéristiques sélectionnées : [6, 7, 12, 16, 20, 25, 26, 36, 42, 49, 52, 64, 67, 69, 78, 85, 88, 95, 102, 105, 111, 112, 120, 124]
#
# Étape 100/100
# Récompense: 0.2975, Retour cumulé: 33.9359
# Caractéristiques sélectionnées : [4, 12, 14, 33, 34, 38, 40, 41, 42, 47, 57, 58, 59, 62, 77, 80, 83, 87, 98, 112, 114, 122, 123]
#
#
# Statistiques de l'épisode 36:
# Retour total: 33.9359
#
# ==================== Épisode 37/100 ====================
#
# Étape 1/100
# Récompense: 0.3736, Retour cumulé: 0.3736
# Caractéristiques sélectionnées : [0, 5, 6, 7, 13, 20, 34, 40, 67, 72, 75, 79, 86, 100, 102, 109, 111, 114, 118, 122, 123, 125, 126, 127]
#
# Étape 21/100
# Récompense: 0.3662, Retour cumulé: 7.1566
# Caractéristiques sélectionnées : [0, 6, 7, 9, 10, 14, 19, 20, 23, 24, 25, 33, 38, 42, 55, 56, 58, 59, 70, 73, 79, 81, 93, 99, 110, 112, 122]
#
# Étape 41/100
# Récompense: 0.3094, Retour cumulé: 14.0197
# Caractéristiques sélectionnées : [0, 1, 6, 7, 18, 20, 29, 34, 40, 46, 57, 65, 67, 79, 82, 100, 102, 103, 109, 111, 114, 115, 125, 126, 127]
#
# Étape 61/100
# Récompense: 0.3449, Retour cumulé: 21.1153
# Caractéristiques sélectionnées : [8, 9, 14, 16, 20, 23, 25, 32, 34, 37, 40, 46, 48, 52, 53, 61, 62, 71, 72, 76, 88, 90, 93, 98, 109, 110, 125]
#
# Étape 81/100
# Récompense: 0.3288, Retour cumulé: 28.2548
# Caractéristiques sélectionnées : [10, 14, 19, 24, 25, 28, 38, 52, 55, 56, 59, 70, 72, 79, 81, 82, 83, 89, 92, 93, 99, 100, 107, 110, 112, 122]
#
# Étape 100/100
# Récompense: 0.4371, Retour cumulé: 34.5454
# Caractéristiques sélectionnées : [8, 9, 11, 24, 32, 34, 37, 39, 48, 52, 61, 70, 71, 73, 76, 83, 90, 93, 98, 106, 109, 115, 125, 127]
#
#
# Statistiques de l'épisode 37:
# Retour total: 34.5454
#
# ==================== Épisode 38/100 ====================
#
# Étape 1/100
# Récompense: 0.2841, Retour cumulé: 0.2841
# Caractéristiques sélectionnées : [13, 14, 15, 16, 19, 23, 27, 28, 29, 35, 36, 37, 42, 44, 53, 60, 62, 69, 83, 93, 98, 107, 109, 115, 125]
#
# Étape 21/100
# Récompense: 0.2877, Retour cumulé: 6.9946
# Caractéristiques sélectionnées : [15, 21, 23, 28, 31, 42, 45, 47, 60, 65, 68, 69, 77, 78, 93, 96, 108, 109, 110, 111, 115, 117, 119, 125, 127]
#
# Étape 41/100
# Récompense: 0.3534, Retour cumulé: 14.0637
# Caractéristiques sélectionnées : [10, 14, 22, 24, 25, 27, 38, 45, 49, 52, 55, 56, 59, 60, 65, 70, 79, 81, 90, 93, 99, 100, 103, 112, 119, 122]
#
# Étape 61/100
# Récompense: 0.3765, Retour cumulé: 21.1906
# Caractéristiques sélectionnées : [8, 9, 13, 17, 32, 34, 37, 41, 48, 52, 54, 60, 61, 71, 76, 90, 93, 98, 99, 103, 109, 123, 125]
#
# Étape 81/100
# Récompense: 0.3488, Retour cumulé: 28.0625
# Caractéristiques sélectionnées : [6, 13, 14, 16, 19, 23, 24, 26, 27, 29, 35, 37, 41, 42, 60, 69, 70, 72, 81, 85, 93, 96, 97, 98, 107, 125]
#
# Étape 100/100
# Récompense: 0.3368, Retour cumulé: 34.4014
# Caractéristiques sélectionnées : [0, 14, 16, 19, 23, 27, 29, 34, 35, 37, 38, 42, 50, 60, 69, 77, 80, 82, 88, 89, 93, 98, 107, 109, 122, 124, 125]
#
#
# Statistiques de l'épisode 38:
# Retour total: 34.4014
#
# ==================== Épisode 39/100 ====================
#
# Étape 1/100
# Récompense: 0.3678, Retour cumulé: 0.3678
# Caractéristiques sélectionnées : [14, 16, 19, 23, 27, 29, 35, 37, 41, 42, 53, 60, 67, 69, 83, 85, 86, 93, 95, 98, 100, 107, 109, 119, 125]
#
# Étape 21/100
# Récompense: 0.3833, Retour cumulé: 7.2376
# Caractéristiques sélectionnées : [0, 6, 7, 10, 11, 20, 22, 27, 34, 40, 42, 75, 79, 85, 91, 92, 99, 100, 102, 108, 109, 111, 114, 125, 126, 127]
#
# Étape 41/100
# Récompense: 0.3217, Retour cumulé: 14.0714
# ...
#
# Étape 41/100
# Récompense: 0.5164, Retour cumulé: 23.0623
# Caractéristiques sélectionnées : [19, 22, 37, 39, 42, 45, 53, 54, 55, 56, 60, 61, 87, 88, 90, 95, 97, 101, 103, 106, 107, 108]
#
# Étape 61/100
# Récompense: 0.5564, Retour cumulé: 33.9201
# Caractéristiques sélectionnées : [0, 8, 10, 19, 23, 40, 47, 53, 56, 62, 63, 71, 73, 74, 78, 79, 83, 84, 90, 94, 97, 99, 106, 112, 113, 124]
#
# Étape 81/100
# Récompense: 0.6143, Retour cumulé: 45.0606
# Caractéristiques sélectionnées : [0, 3, 6, 7, 10, 20, 34, 40, 63, 64, 70, 79, 90, 100, 102, 109, 111, 114, 116, 117, 119, 125, 126, 127]
#
# Étape 100/100
# Récompense: 0.6437, Retour cumulé: 55.8469
# Caractéristiques sélectionnées : [4, 12, 18, 33, 34, 37, 42, 47, 55, 57, 58, 59, 62, 70, 73, 74, 77, 80, 83, 87, 114, 117, 118, 124]
#
#
# Statistiques de l'épisode 89:
# Retour total: 55.8469
#
# ==================== Épisode 90/100 ====================
#
# Étape 1/100
# Récompense: 0.5579, Retour cumulé: 0.5579
# Caractéristiques sélectionnées : [0, 10, 27, 43, 46, 47, 53, 60, 62, 66, 73, 78, 79, 83, 84, 85, 86, 90, 94, 99, 100, 106, 112]
#
# Étape 21/100
# Récompense: 0.4853, Retour cumulé: 11.5049
# Caractéristiques sélectionnées : [0, 5, 6, 7, 12, 16, 20, 25, 29, 42, 52, 67, 75, 78, 83, 85, 91, 95, 102, 111, 118, 120, 124, 126, 127]
#
# Étape 41/100
# Récompense: 0.4752, Retour cumulé: 22.4700
# Caractéristiques sélectionnées : [6, 7, 9, 16, 20, 21, 25, 26, 42, 46, 52, 56, 59, 67, 72, 78, 85, 90, 95, 102, 111, 117, 120, 121, 122, 124]
#
# Étape 61/100
# Récompense: 0.5796, Retour cumulé: 33.5743
# Caractéristiques sélectionnées : [8, 9, 11, 32, 34, 37, 44, 48, 52, 61, 71, 76, 78, 90, 93, 97, 98, 109, 115, 119, 120, 125]
#
# Étape 81/100
# Récompense: 0.5733, Retour cumulé: 44.6999
# Caractéristiques sélectionnées : [6, 7, 16, 20, 25, 42, 48, 52, 67, 68, 78, 85, 91, 92, 95, 102, 111, 119, 120, 121, 124]
#
# Étape 100/100
# Récompense: 0.5642, Retour cumulé: 55.1832
# Caractéristiques sélectionnées : [10, 14, 18, 24, 25, 27, 36, 38, 55, 56, 59, 70, 79, 80, 81, 93, 94, 97, 99, 112, 114, 118, 122]
#
#
# Statistiques de l'épisode 90:
# Retour total: 55.1832
#
# ==================== Épisode 91/100 ====================
#
# Étape 1/100
# Récompense: 0.5845, Retour cumulé: 0.5845
# Caractéristiques sélectionnées : [6, 7, 13, 16, 20, 25, 42, 52, 64, 67, 78, 81, 85, 88, 89, 95, 102, 111, 120, 122, 124, 126]
#
# Étape 21/100
# Récompense: 0.5037, Retour cumulé: 11.5532
# Caractéristiques sélectionnées : [6, 7, 8, 12, 16, 17, 20, 25, 27, 37, 42, 47, 52, 67, 77, 78, 83, 85, 86, 90, 95, 102, 103, 111, 117, 120, 124]
#
# Étape 41/100
# Récompense: 0.4948, Retour cumulé: 22.4359
# Caractéristiques sélectionnées : [6, 7, 16, 20, 22, 25, 32, 42, 52, 59, 67, 70, 76, 78, 83, 85, 91, 95, 102, 111, 120, 124, 127]
#
# Étape 61/100
# Récompense: 0.5719, Retour cumulé: 33.9594
# Caractéristiques sélectionnées : [2, 6, 7, 15, 16, 20, 25, 30, 42, 52, 66, 67, 78, 85, 95, 102, 103, 106, 111, 116, 120, 123, 124]
#
# Étape 81/100
# Récompense: 0.5338, Retour cumulé: 44.9915
# Caractéristiques sélectionnées : [0, 10, 12, 14, 16, 24, 25, 38, 50, 51, 55, 56, 59, 62, 65, 66, 70, 79, 81, 93, 99, 112, 113, 114, 117, 122, 125]
#
# Étape 100/100
# Récompense: 0.5391, Retour cumulé: 55.6413
# Caractéristiques sélectionnées : [10, 14, 15, 22, 24, 25, 38, 42, 49, 55, 56, 59, 69, 70, 75, 79, 80, 81, 93, 98, 99, 112, 118, 122]
#
#
# Statistiques de l'épisode 91:
# Retour total: 55.6413
#
# ==================== Épisode 92/100 ====================
#
# Étape 1/100
# Récompense: 0.4723, Retour cumulé: 0.4723
# Caractéristiques sélectionnées : [14, 15, 16, 19, 20, 23, 27, 29, 35, 37, 42, 49, 56, 60, 63, 69, 93, 94, 98, 107, 112, 123, 124, 125]
#
# Étape 21/100
# Récompense: 0.5224, Retour cumulé: 11.3590
# Caractéristiques sélectionnées : [6, 7, 13, 16, 18, 20, 25, 37, 39, 41, 42, 52, 57, 58, 60, 61, 67, 78, 85, 95, 102, 107, 111, 120, 124, 127]
#
# Étape 41/100
# Récompense: 0.5373, Retour cumulé: 22.5292
# Caractéristiques sélectionnées : [0, 6, 7, 10, 16, 20, 21, 34, 40, 46, 50, 65, 66, 73, 77, 79, 92, 99, 100, 102, 109, 111, 114, 125, 126, 127]
#
# Étape 61/100
# Récompense: 0.5100, Retour cumulé: 33.9465
# Caractéristiques sélectionnées : [4, 6, 9, 12, 22, 33, 34, 42, 47, 55, 57, 58, 59, 62, 77, 80, 83, 87, 110, 114, 119, 125, 126]
#
# Étape 81/100
# Récompense: 0.5258, Retour cumulé: 45.5279
# Caractéristiques sélectionnées : [1, 10, 19, 24, 37, 38, 39, 42, 45, 48, 52, 53, 54, 55, 56, 61, 75, 87, 95, 96, 104, 106, 107, 108, 122]
#
# Étape 100/100
# Récompense: 0.5765, Retour cumulé: 56.4187
# Caractéristiques sélectionnées : [3, 10, 12, 14, 24, 25, 37, 38, 47, 51, 54, 55, 56, 59, 62, 70, 79, 81, 82, 90, 93, 99, 112, 122]
#
#
# Statistiques de l'épisode 92:
# Retour total: 56.4187
#
# ==================== Épisode 93/100 ====================
#
# Étape 1/100
# Récompense: 0.5499, Retour cumulé: 0.5499
# Caractéristiques sélectionnées : [10, 14, 17, 21, 24, 25, 26, 38, 44, 55, 56, 59, 70, 79, 81, 84, 90, 93, 99, 101, 102, 112, 114, 120, 122]
#
# Étape 21/100
# Récompense: 0.5805, Retour cumulé: 11.7644
# Caractéristiques sélectionnées : [11, 18, 19, 25, 33, 37, 39, 42, 45, 50, 53, 54, 55, 56, 61, 87, 92, 95, 102, 106, 107, 108]
#
# Étape 41/100
# Récompense: 0.5814, Retour cumulé: 23.1743
# Caractéristiques sélectionnées : [0, 1, 4, 5, 7, 12, 20, 29, 39, 52, 55, 58, 60, 62, 63, 72, 75, 78, 81, 98, 102, 108, 109, 112, 113, 123, 126]
#
# Étape 61/100
# Récompense: 0.4871, Retour cumulé: 34.5660
# Caractéristiques sélectionnées : [9, 14, 15, 16, 17, 19, 23, 27, 29, 30, 35, 37, 38, 42, 60, 65, 66, 69, 93, 98, 107, 125]
#
# Étape 81/100
# Récompense: 0.6328, Retour cumulé: 46.2225
# Caractéristiques sélectionnées : [7, 17, 19, 20, 37, 39, 42, 43, 45, 53, 54, 55, 56, 59, 60, 61, 78, 81, 87, 95, 106, 107, 108, 122, 123]
#
# Étape 100/100
# Récompense: 0.5577, Retour cumulé: 56.9071
# Caractéristiques sélectionnées : [10, 14, 16, 22, 24, 25, 38, 51, 55, 56, 59, 69, 70, 73, 79, 81, 93, 99, 104, 112, 115, 122, 125, 127]
#
#
# Statistiques de l'épisode 93:
# Retour total: 56.9071
#
# ==================== Épisode 94/100 ====================
#
# Étape 1/100
# Récompense: 0.5064, Retour cumulé: 0.5064
# Caractéristiques sélectionnées : [7, 15, 23, 28, 29, 31, 38, 42, 44, 60, 62, 68, 69, 75, 92, 93, 96, 97, 100, 110, 113, 115, 117, 119, 125, 126, 127]
#
# Étape 21/100
# Récompense: 0.5925, Retour cumulé: 11.9672
# Caractéristiques sélectionnées : [0, 5, 10, 41, 46, 47, 50, 53, 57, 62, 67, 73, 78, 79, 83, 84, 90, 93, 94, 99, 102, 106, 112, 114, 115, 119]
#
# Étape 41/100
# Récompense: 0.6088, Retour cumulé: 23.5852
# Caractéristiques sélectionnées : [9, 10, 11, 14, 17, 24, 25, 27, 38, 39, 42, 55, 56, 59, 70, 79, 81, 93, 97, 99, 103, 112, 114, 122]
#
# Étape 61/100
# Récompense: 0.6640, Retour cumulé: 35.4944
# Caractéristiques sélectionnées : [10, 14, 16, 24, 25, 28, 30, 37, 38, 40, 55, 56, 59, 69, 70, 79, 80, 81, 83, 90, 93, 99, 102, 112, 122]
#
# Étape 81/100
# Récompense: 0.5519, Retour cumulé: 46.7951
# Caractéristiques sélectionnées : [10, 13, 17, 19, 37, 39, 42, 45, 53, 54, 55, 56, 57, 61, 62, 87, 88, 95, 106, 107, 108, 115]
#
# Étape 100/100
# Récompense: 0.5801, Retour cumulé: 57.5474
# Caractéristiques sélectionnées : [10, 19, 27, 37, 38, 39, 42, 45, 49, 53, 54, 55, 56, 61, 64, 69, 82, 84, 87, 89, 95, 106, 107, 108, 119]
#
#
# Statistiques de l'épisode 94:
# Retour total: 57.5474
#
# ==================== Épisode 95/100 ====================
#
# Étape 1/100
# Récompense: 0.5671, Retour cumulé: 0.5671
# Caractéristiques sélectionnées : [10, 14, 16, 19, 22, 23, 27, 29, 32, 35, 37, 42, 60, 65, 69, 84, 85, 93, 98, 105, 107, 125]
#
# Étape 21/100
# Récompense: 0.5817, Retour cumulé: 12.0253
# Caractéristiques sélectionnées : [6, 10, 19, 24, 32, 37, 39, 42, 45, 48, 52, 53, 54, 55, 56, 60, 61, 79, 87, 88, 95, 100, 106, 107, 108, 112, 115]
#
# Étape 41/100
# Récompense: 0.6252, Retour cumulé: 23.5051
# Caractéristiques sélectionnées : [0, 10, 21, 30, 31, 47, 49, 53, 58, 62, 63, 73, 78, 79, 83, 84, 90, 94, 96, 97, 99, 106, 112, 118, 121, 126]
#
# Étape 61/100
# Récompense: 0.5805, Retour cumulé: 35.4147
# Caractéristiques sélectionnées : [2, 6, 7, 8, 9, 13, 32, 33, 34, 37, 48, 52, 61, 69, 71, 76, 90, 93, 98, 109, 122, 125]
#
# Étape 81/100
# Récompense: 0.5314, Retour cumulé: 46.7521
# Caractéristiques sélectionnées : [0, 4, 5, 7, 9, 12, 52, 58, 60, 61, 63, 71, 78, 80, 81, 89, 99, 102, 106, 109, 112, 123]
#
# Étape 100/100
# Récompense: 0.6261, Retour cumulé: 57.5288
# Caractéristiques sélectionnées : [4, 12, 16, 26, 33, 34, 42, 47, 57, 58, 59, 62, 77, 78, 80, 83, 87, 93, 99, 103, 109, 113, 114, 120]
#
#
# Statistiques de l'épisode 95:
# Retour total: 57.5288
#
# ==================== Épisode 96/100 ====================
#
# Étape 1/100
# Récompense: 0.6526, Retour cumulé: 0.6526
# Caractéristiques sélectionnées : [0, 4, 12, 16, 23, 25, 33, 34, 38, 42, 47, 57, 58, 59, 60, 62, 77, 78, 80, 83, 84, 87, 96, 114, 119, 123]
#
# Étape 21/100
# Récompense: 0.5768, Retour cumulé: 12.2018
# Caractéristiques sélectionnées : [15, 16, 23, 28, 31, 37, 42, 47, 53, 60, 61, 68, 69, 78, 85, 93, 106, 110, 112, 115, 117, 119, 122, 123, 125, 127]
#
# Étape 41/100
# Récompense: 0.6240, Retour cumulé: 24.3600
# Caractéristiques sélectionnées : [0, 6, 7, 12, 20, 34, 40, 58, 61, 68, 71, 79, 87, 100, 102, 105, 109, 111, 114, 125, 126, 127]
#
# Étape 61/100
# Récompense: 0.5640, Retour cumulé: 36.4420
# Caractéristiques sélectionnées : [14, 15, 16, 19, 23, 27, 29, 35, 37, 41, 42, 53, 58, 60, 62, 69, 70, 80, 93, 98, 107, 111, 114, 125]
#
# Étape 81/100
# Récompense: 0.5803, Retour cumulé: 48.0624
# Caractéristiques sélectionnées : [0, 4, 5, 7, 12, 25, 34, 47, 52, 58, 60, 63, 76, 78, 80, 81, 84, 102, 109, 112, 114, 115, 123, 126]
#
# Étape 100/100
# Récompense: 0.6601, Retour cumulé: 59.2091
# Caractéristiques sélectionnées : [8, 9, 31, 32, 34, 37, 39, 44, 48, 52, 55, 61, 70, 71, 72, 74, 76, 79, 90, 93, 98, 109, 125]
#
#
# Statistiques de l'épisode 96:
# Retour total: 59.2091
#
# ==================== Épisode 97/100 ====================
#
# Étape 1/100
# Récompense: 0.6419, Retour cumulé: 0.6419
# Caractéristiques sélectionnées : [0, 2, 4, 5, 7, 12, 26, 34, 42, 52, 58, 60, 63, 64, 78, 81, 83, 85, 101, 102, 108, 109, 112, 123]
#
# Étape 21/100
# Récompense: 0.6603, Retour cumulé: 12.5458
# Caractéristiques sélectionnées : [10, 14, 24, 25, 37, 38, 41, 55, 56, 59, 64, 70, 79, 81, 83, 87, 93, 99, 112, 121, 122, 126]
#
# Étape 41/100
# Récompense: 0.5356, Retour cumulé: 24.2433
# Caractéristiques sélectionnées : [1, 14, 16, 19, 21, 23, 25, 27, 29, 35, 37, 42, 48, 58, 60, 64, 69, 75, 85, 93, 98, 102, 107, 112, 118, 125]
#
# Étape 61/100
# Récompense: 0.6142, Retour cumulé: 35.8975
# Caractéristiques sélectionnées : [0, 10, 15, 17, 25, 28, 47, 53, 62, 73, 74, 78, 79, 83, 84, 90, 93, 94, 99, 106, 112, 116, 121, 122, 127]
#
# Étape 81/100
# Récompense: 0.6664, Retour cumulé: 47.8438
# Caractéristiques sélectionnées : [0, 6, 7, 8, 20, 34, 40, 57, 69, 79, 96, 100, 102, 109, 111, 114, 121, 123, 125, 126, 127]
#
# Étape 100/100
# Récompense: 0.5906, Retour cumulé: 58.8005
# Caractéristiques sélectionnées : [14, 16, 19, 23, 27, 29, 35, 36, 37, 42, 57, 60, 61, 64, 69, 81, 89, 93, 94, 95, 98, 107, 123, 125]
#
#
# Statistiques de l'épisode 97:
# Retour total: 58.8005
#
# ==================== Épisode 98/100 ====================
#
# Étape 1/100
# Récompense: 0.5979, Retour cumulé: 0.5979
# Caractéristiques sélectionnées : [18, 19, 23, 29, 37, 39, 42, 45, 53, 54, 55, 56, 61, 75, 87, 95, 97, 105, 106, 107, 108, 125, 126]
#
# Étape 21/100
# Récompense: 0.6324, Retour cumulé: 12.5620
# Caractéristiques sélectionnées : [0, 6, 7, 20, 27, 28, 34, 37, 40, 50, 55, 69, 79, 98, 100, 102, 109, 111, 114, 125, 126, 127]
#
# Étape 41/100
# Récompense: 0.5662, Retour cumulé: 24.8642
# Caractéristiques sélectionnées : [3, 10, 14, 19, 24, 25, 38, 55, 56, 59, 69, 70, 79, 81, 87, 91, 93, 95, 96, 99, 109, 112, 114, 122]
#
# Étape 61/100
# Récompense: 0.5320, Retour cumulé: 36.4477
# Caractéristiques sélectionnées : [3, 4, 12, 17, 21, 27, 29, 33, 34, 42, 47, 54, 57, 58, 59, 62, 64, 77, 80, 83, 87, 113, 114]
#
# Étape 81/100
# Récompense: 0.6154, Retour cumulé: 48.1852
# Caractéristiques sélectionnées : [8, 9, 32, 34, 37, 48, 52, 61, 66, 67, 71, 75, 76, 77, 90, 93, 98, 107, 109, 110, 120, 122, 125]
#
# Étape 100/100
# Récompense: 0.6717, Retour cumulé: 59.6412
# Caractéristiques sélectionnées : [0, 6, 7, 12, 16, 18, 20, 32, 34, 40, 57, 66, 68, 79, 99, 100, 102, 103, 109, 111, 114, 124, 125, 126, 127]
#
#
# Statistiques de l'épisode 98:
# Retour total: 59.6412
#
# ==================== Épisode 99/100 ====================
#
# Étape 1/100
# Récompense: 0.6755, Retour cumulé: 0.6755
# Caractéristiques sélectionnées : [0, 4, 5, 7, 12, 21, 23, 40, 49, 51, 52, 54, 58, 60, 63, 70, 78, 81, 84, 102, 109, 110, 112, 121, 123]
#
# Étape 21/100
# Récompense: 0.5621, Retour cumulé: 12.5253
# Caractéristiques sélectionnées : [4, 8, 9, 25, 32, 34, 37, 48, 50, 52, 53, 54, 61, 71, 76, 90, 93, 96, 97, 98, 101, 109, 113, 116, 125]
#
# Étape 41/100
# Récompense: 0.6426, Retour cumulé: 24.3675
# Caractéristiques sélectionnées : [0, 4, 5, 7, 12, 14, 52, 58, 60, 63, 71, 73, 78, 81, 89, 102, 104, 109, 112, 113, 119, 123]
#
# Étape 61/100
# Récompense: 0.4758, Retour cumulé: 35.9880
# Caractéristiques sélectionnées : [0, 4, 5, 6, 7, 11, 12, 16, 37, 46, 52, 56, 58, 60, 63, 74, 78, 81, 96, 102, 108, 109, 112, 120, 123]
#
# Étape 81/100
# Récompense: 0.6155, Retour cumulé: 47.8930
# Caractéristiques sélectionnées : [0, 6, 7, 20, 34, 35, 36, 40, 47, 55, 67, 68, 79, 84, 90, 100, 102, 103, 109, 111, 112, 114, 125, 126, 127]
#
# Étape 100/100
# Récompense: 0.6289, Retour cumulé: 59.1362
# Caractéristiques sélectionnées : [0, 7, 15, 23, 24, 28, 31, 41, 42, 43, 44, 51, 57, 60, 68, 69, 70, 93, 107, 110, 115, 117, 119, 125, 127]
#
#
# Statistiques de l'épisode 99:
# Retour total: 59.1362
#
# ==================== Épisode 100/100 ====================
#
# Étape 1/100
# Récompense: 0.5540, Retour cumulé: 0.5540
# Caractéristiques sélectionnées : [0, 6, 7, 20, 34, 39, 40, 41, 50, 60, 66, 69, 79, 100, 102, 109, 111, 114, 117, 118, 125, 126, 127]
#
# Étape 21/100
# Récompense: 0.5716, Retour cumulé: 12.4310
# Caractéristiques sélectionnées : [6, 7, 16, 20, 25, 27, 28, 33, 42, 47, 50, 52, 67, 69, 78, 85, 91, 95, 101, 102, 104, 111, 120, 124]
#
# Étape 41/100
# Récompense: 0.5975, Retour cumulé: 24.0052
# Caractéristiques sélectionnées : [6, 8, 9, 22, 32, 34, 37, 44, 48, 52, 61, 65, 71, 76, 83, 86, 90, 93, 98, 103, 109, 111, 125]
#
# Étape 61/100
# Récompense: 0.5922, Retour cumulé: 35.8676
# Caractéristiques sélectionnées : [17, 19, 37, 39, 40, 42, 45, 50, 53, 54, 55, 56, 59, 61, 83, 87, 88, 94, 95, 101, 103, 106, 107, 108, 125]
#
# Étape 81/100
# Récompense: 0.4910, Retour cumulé: 47.5964
# Caractéristiques sélectionnées : [6, 7, 14, 16, 20, 25, 42, 47, 52, 67, 70, 78, 82, 85, 93, 94, 95, 102, 111, 120, 124]
#
# Étape 100/100
# Récompense: 0.5661, Retour cumulé: 59.1875
# Caractéristiques sélectionnées : [0, 5, 6, 7, 20, 34, 40, 44, 46, 58, 59, 62, 79, 80, 100, 102, 105, 109, 111, 114, 125, 126, 127]
#
#
# Statistiques de l'épisode 100:
# Retour total: 59.1875
#
# Statistiques finales d'entraînement:
# Nombre total d'épisodes complétés: 100
# Meilleur retour: 59.6412
# Retour moyen: 39.8135
#
# Meilleures caractéristiques par classe :
# Meilleures caractéristiques pour la classe 0: [6, 7, 16, 20, 25, 42, 52, 67, 78, 85, 95, 102, 111, 120, 124]
# Meilleures caractéristiques pour la classe 1: [0, 10, 47, 53, 62, 73, 78, 79, 83, 84, 90, 94, 99, 106, 112]
# Meilleures caractéristiques pour la classe 2: [10, 14, 24, 25, 38, 55, 56, 59, 70, 79, 81, 93, 99, 112, 122]
# Meilleures caractéristiques pour la classe 3: [8, 9, 32, 34, 37, 48, 52, 61, 71, 76, 90, 93, 98, 109, 125]
# Meilleures caractéristiques pour la classe 4: [0, 6, 7, 20, 34, 40, 79, 100, 102, 109, 111, 114, 125, 126, 127]
# Meilleures caractéristiques pour la classe 5: [19, 37, 39, 42, 45, 53, 54, 55, 56, 61, 87, 95, 106, 107, 108]
# Meilleures caractéristiques pour la classe 6: [0, 4, 5, 7, 12, 52, 58, 60, 63, 78, 81, 102, 109, 112, 123]
# Meilleures caractéristiques pour la classe 7: [14, 16, 19, 23, 27, 29, 35, 37, 42, 60, 69, 93, 98, 107, 125]
# Meilleures caractéristiques pour la classe 8: [15, 23, 28, 31, 42, 60, 68, 69, 93, 110, 115, 117, 119, 125, 127]
# Meilleures caractéristiques pour la classe 9: [4, 12, 33, 34, 42, 47, 57, 58, 59, 62, 77, 80, 83, 87, 114]
#
# Évaluation sur l'ensemble de test:
# Total Accuracy: 0.8444, Number of Batches: 32
